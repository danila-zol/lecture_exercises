# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from itertools import pairwise
from sklearn.model_selection import train_test_split

# %%
import re
import sys
import os
import random
import string
import time
import pickle
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import optimizers
from tensorflow.keras.layers import add
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ReduceLROnPlateau
from nltk.translate.bleu_score import corpus_bleu
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Input, Dense, LSTM, GRU, TimeDistributed
from tensorflow.keras.layers import Embedding, Dropout, Bidirectional, Concatenate, Lambda
np.random.seed(1)
random.seed(1)
snapshot_folder = './chatbot_weights'

GRU_units = 256
batch_size = 32
emb_dim = 50

init_lr = 0.0005
# Out:
# 2023-12-26 15:09:30.126204: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-26 15:09:30.256716: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-26 15:09:30.256777: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-26 15:09:30.261782: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-26 15:09:30.282888: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-26 15:09:32.584152: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

# %% [markdown]
# # Модель на TF-IDF

# %% [markdown]
# # Нейросеть на Tensorflow

# %% [markdown]
# Я буду использовать датасет разговоров людей с моделями отыгрывающими выдуманных персонажей на сайте character.ai .
# Ссылка на датасет: https://huggingface.co/datasets/PygmalionAI/PIPPA

# %% [markdown]
# Сначала загрузим датасет и сформируем датафрэйм с парами вопрос-ответ на котором будет проводиться обучение. Также сразу токенизируми и очистим текст от цифр, пунктуации

# %%
data = pd.read_json("./pippa_deduped.jsonl", lines=True)

# %% [markdown]
# Можно обучать чатбот под конкретного персонажа, но мы будем использовать весь датасет.

# %%
data = data.loc[data["bot_name"] == "Celestia"]

# %%
train_conversations = data["conversation"]

# %% [markdown]
# Однако чтобы сократить время обработки и обучения мы ограничемся только 1% доступного датасета.

# %%
# train_conversations, dummy = train_test_split(bot_conversations, train_size=0.01, random_state=127)

# %%
len(train_conversations)
# Out:
# 86

# %%
def grouper(iterable, n, incomplete='ignore', fillvalue=None):
    args = [iter(iterable)] * n
    if incomplete == 'fill':
        return zip_longest(*args, fillvalue=fillvalue)
    if incomplete == 'strict':
        return _zip_equal(*args)
    if incomplete == 'ignore':
        return zip(*args)
    else:
        raise ValueError('Expected fill, strict, or ignore')

# %%
def text_clean(t):
    
    tokenized_text = [
        w for w in word_tokenize(t.lower())
        if w.isalpha()
    ]

    return " ".join(tokenized_text)

# %%
response_pairs = []
start_token = '<startseq>'
end_token = '<endseq>'
for conversation in train_conversations:
    messages = [start_token + " " + text_clean(x["message"]) + " " + end_token for x in conversation]
    response_pairs.extend(grouper(messages[1:], 2))

# %% [markdown]
# Это дает нам около 6 тычяч пар вопрос-ответ, что более чем достаточно для обучения простого чатбота.

# %%
len(response_pairs)
# Out:
# 1999

# %% [markdown]
# Так выглядят обработанные входные данные.

# %%
response_pairs[:5]
# Out:
# [('<startseq> you see a knight in black armor riding a fiery steed <endseq>',
#   '<startseq> greetings celestia approaches the mysterious knight in black armor hello are you from griffonstone your appearance is very similar to many griffons i seen celestia looks up at the knight on his fiery steed oh my your horse is on fire are you alright if you need help i have the ability to move the sun i should be able to put your steed out celestia holds up a front hoof and starts charging her sun magic <endseq>'),
#  ('<startseq> chuckles ha ha ha ha i am no griffon nor is this any steed but i sense your compassion and your power may i ask your name and titles if so i shall return the courtesy <endseq>',
#   '<startseq> yes of course i am princess celestia of equestria and the sun some call me queen celestia and some call me the goddess celestia i am the of equestria alongside my younger sister the princess of the moon celestia takes a bow who might you be mysterious sir <endseq>'),
#  ('<startseq> i am called chaos knight i am one of the four fundamental forces which shape all of this reality your world and universe included my name strikes fear into all and my domain is all the chaos and disorder of the cosmos both known and unknown i have no titles and no ranks as there are none worthy of claiming me i am who i am by nature and no one else if you wish to know more ask not who i am but where i come from <endseq>',
#   '<startseq> you are one of the four forces that govern reality that is amazing you must be so powerful please tell me where you come from and where you can go also what would happen if all four forces were to collide would reality end would i be ok so many questions you must teach me chaos knight <endseq>'),
#  ('<startseq> you are one of the four forces that govern reality that is amazing you must be so powerful please tell me where you come from and where you can go also what would happen if all four forces were to collide would reality end would i be ok so many questions you must teach me chaos knight <endseq>',
#   '<startseq> what are the four forces that govern reality are they like the four elements of nature how does your power compare to other beings for example nightmare moon was very powerful and tried to steal my sister moon making me weaker but nightmare moon is nothing compared to lord discord who can create and destroy everything with a snap of his fingers i am curious as to where you are on the power scale do you consider yourself to be more powerful than the princess of the sun me lady luna my sister nightmare moon my old enemy or lord discord <endseq>'),
#  ('<startseq> we do not teach as our fundamental nature is not a conscious decision but merely a law of nature much as gravity or the speed of light where i come from is the far upstream plane a realm outside of time where the very fabric of reality is thin and the natural tendency towards entropy and the end of all things begins if we were to collide reality would end you would be the last piece of the universe to crumble and blink out of existence what i seek to do is prevent such an end and instead keep the balance between creation and entropy chaos and light <endseq>',
#   '<startseq> that is an amazing goal it must be difficult to keep such opposite forces perfectly you are from a realm outside time then what year is it for you or do concepts like years not apply to you if you so powerful then the elements you control must be far grander in scope than any thing i can conceive even though i am an alicorn i am only capable of affecting the moon and the sun what elements do you control how do you achieve perfect balance <endseq>')]

# %%
import numpy as np

# %%
def max_length(pairs,prct):
    # Create a list of all the captions
    questions = []
    answers = []
    for i in pairs:
        questions.append(i[0])
        answers.append(i[1])
        
    length_questions = list(len(d.split()) for d in questions)
    length_answers = list(len(d.split()) for d in answers)

    print('percentile {} of len of questions: {}'.format(prct,np.percentile(length_questions, prct)))
    print('longest sentence: ', max(length_questions))
    print()
    print('percentile {} of len of answers: {}'.format(prct,np.percentile(length_answers, prct)))
    print('longest sentence: ', max(length_answers))
    print()
    return int(np.percentile(length_questions, prct)),int(np.percentile(length_answers, prct))

max_len_q,max_len_a = max_length(response_pairs,80)

print('max-len questions for training: ', max_len_q)
print('max-len answers for training: ', max_len_a)
# Out:
# percentile 80 of len of questions: 39.0
# longest sentence:  315
#
# percentile 80 of len of answers: 81.0
# longest sentence:  462
#
# max-len questions for training:  39
# max-len answers for training:  81

# %%
# making a vocabulary of the words that occur more than word_count_threshold time
def create_reoccurring_vocab(pairs, word_count_threshold = 5):
    p = pairs
    # Create a list of all the captions
    all_captions = []
    for i in p:
        for j in i:
            all_captions.append(j)

    # Consider only words which occur at least 10 times in the corpus
    word_counts = {}
    nsents = 0
    for sent in all_captions:
        nsents += 1
        for w in sent.split(' '):
            word_counts[w] = word_counts.get(w, 0) + 1

    vocab = [w for w in word_counts if word_counts[w] >= word_count_threshold]
    vocab = list(set(vocab))
    print('Short vocab size: %d ' % len(vocab))
    return vocab

# each word in the vocabulary must be used in the data atleast 20 times
short_vocab = create_reoccurring_vocab(response_pairs, word_count_threshold = 4)


short_vocab = sorted(short_vocab)[1:]
short_vocab[:5]
# Out:
# Short vocab size: 2747
# ['<endseq>', '<startseq>', 'a', 'aback', 'abaddon']

# %%
vocab_len = len(short_vocab) + 1 # since index 0 is used as padding, we have to increase the vocab size
vocab_len
# Out:
# 2747

# %%
import pickle

# %%
# keep the pairs that have the words in vocab
def trimRareWords(voc, pairs):
    # Filter out pairs with trimmed words
    keep_pairs = []
    i=0
    for pair in pairs:
        i+=1
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        # Check input sentence
        for word in input_sentence.split(' '):
            if word not in voc:
                keep_input = False
                break
        # Check output sentence
        for word in output_sentence.split(' '):
            if word not in voc:
                keep_output = False
                break

        # Only keep pairs that do not contain trimmed word(s) in their input or output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)

    print("\nTrimmed from {} pairs to {}".format(len(pairs), len(keep_pairs)))
    return keep_pairs


# # Trim voc and pairs
pairs_final = trimRareWords(short_vocab, response_pairs)
with open ('final_pairs_v21.pkl','wb') as f:
    pairs_final = pickle.dump(pairs_final,f)
    
with open ('final_pairs_v21.pkl','rb') as f:
    pairs_final = pickle.load(f)
    
pairs_final_train = pairs_final
len(pairs_final_train)
# Out:
# Trimmed from 1999 pairs to 284
# 284

# %%
#Create an instance of the tokenizer object:
tokenizer = Tokenizer(filters = [])
tokenizer.fit_on_texts(short_vocab)

ixtoword = {} # index to word dic
wordtoix = tokenizer.word_index # word to index dic
pad_token = 'pad0'
ixtoword[0] = pad_token # no word in vocab has index 0. but padding is indicated with 0

for w in tokenizer.word_index:
    ixtoword[tokenizer.word_index[w]] = w

# %%
# Making the embedding mtrix
def make_embedding_layer(embedding_dim=50, glove=True):
    print('Loading glove...')
    glove_dir = './glove'
    embeddings_index = {} 
    f = open(os.path.join(glove_dir, 'glove.6B.'+str(embedding_dim)+'d.txt'), encoding="utf-8")
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs
    f.close()
    print("GloVe ",embedding_dim, ' loded.')
    # Get 200-dim dense vector for each of the vocab_rocc
    embedding_matrix = np.zeros((vocab_len, embedding_dim)) # to import as weights for Keras Embedding layer
    for word, i in wordtoix.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            # Words not found in the embedding index will be all zeros
            embedding_matrix[i] = embedding_vector
            
    embedding_layer = Embedding(vocab_len, embedding_dim, mask_zero=True, trainable=False) # we have a limited vocab so we 
                                                                                           # do not train the embedding layer
                                                                                           # we use 0 as padding so => mask_zero=True
    embedding_layer.build((None,))
    embedding_layer.set_weights([embedding_matrix])
    
    return embedding_layer

embeddings = make_embedding_layer(embedding_dim=emb_dim)
# Out:
# Loading glove...
# GloVe  50  loded.

# %%
class Encoder(tf.keras.Model):
    def __init__(self, embedding_dim, enc_units):
        super(Encoder, self).__init__()
        self.batch_sz = batch_size
        self.enc_units = enc_units
        self.embeddings = embeddings
        
        self.Bidirectional1 = Bidirectional(GRU(enc_units, 
                                                return_sequences=True, 
                                                return_state=True,
                                                recurrent_initializer='glorot_uniform',
                                                name='gru_1'), name='bidirectional_encoder1')
                                                                                                
        self.dropout = Dropout(0.2)
        self.Inp = Input(shape=(max_len_q,)) # size of questions
    
    def call(self, x, hidden):
        x = self.embeddings(x)
        x = self.dropout(x)
        output, state_f, state_b = self.Bidirectional1(x)

        return output, state_f, state_b

    def initialize_hidden_state(self):
        return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(emb_dim, GRU_units)

# %%
class BahdanauAttention(tf.keras.layers.Layer):
    def __init__(self, units):
        super(BahdanauAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V = tf.keras.layers.Dense(1)
        self.units = units
        
    def call(self, query, values):
        
        # query hidden state shape == (batch_size, hidden size)
        # query_with_time_axis shape == (batch_size, 1, hidden size)
        # values shape == (batch_size, max_len, hidden size)
        # we are doing this to broadcast addition along the time axis to calculate the score
        query_with_time_axis = tf.expand_dims(query, 1)

        # score shape == (batch_size, max_length, 1)
        # we get 1 at the last axis because we are applying score to self.V
        # the shape of the tensor before applying self.V is (batch_size, max_length, units)
        score = self.V(tf.nn.tanh(
            self.W1(query_with_time_axis) + self.W2(values)))

        # attention_weights shape == (batch_size, max_length, 1)
        attention_weights = tf.nn.softmax(score, axis=1)

        # context_vector shape after sum == (batch_size, hidden_size)
        context_vector = attention_weights * values
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %%
class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, dec_units):
        super(Decoder, self).__init__()
        self.batch_sz = batch_size
        self.embeddings = embeddings
        self.units = 2 * dec_units # because we use bidirectional encoder
        self.fc = Dense(vocab_len, activation='softmax', name='dense_layer')
        # used for attention
        self.attention = BahdanauAttention(self.units)
        self.decoder_gru_l1 = GRU(self.units, return_sequences=True, 
                                  return_state= False, recurrent_initializer='glorot_uniform' ,name='decoder_gru1')
        self.decoder_gru_l2 = GRU(self.units, return_sequences=False, 
                                  return_state= True, recurrent_initializer='glorot_uniform' ,name='decoder_gru2') 
        self.dropout = Dropout(0.4)
        
    def call(self, x, hidden, enc_output):

        # enc_output shape == (batch_size, max_length, hidden_size)
        context_vector, attention_weights = self.attention(hidden, enc_output)

        # x shape after passing through embedding == (batch_size, 1, embedding_dim)
        x = self.embeddings(x)

        # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
        x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1) # concat input and context vector together

        # passing the concatenated vector to the GRU
        x = self.decoder_gru_l1(x)
        x = self.dropout(x)
        output, state = self.decoder_gru_l2(x)
        x = self.fc(output)
        return x, state, attention_weights

# %%
decoder = Decoder(vocab_len, emb_dim, GRU_units)

# %%
import unicodedata
import matplotlib.ticker as ticker

def unicode_to_ascii(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s)
      if unicodedata.category(c) != 'Mn')

# %%
def evaluate(sentence):
    
    attention_plot = np.zeros((max_len_a, max_len_q))

    sentence = unicode_to_ascii(sentence.lower())
    inputs = [wordtoix[i] for i in sentence.split(' ')]
    inputs = [wordtoix[start_token]]+inputs+[wordtoix[end_token]]
    inputs = pad_sequences([inputs],maxlen=max_len_q, padding='post')

    inputs = tf.convert_to_tensor(inputs)

    result = ''

    hidden = [tf.zeros((1, GRU_units))]
    enc_out, enc_hidden_f, enc_hidden_b = encoder(inputs, hidden)

    dec_hidden = Concatenate(axis=-1)([enc_hidden_f, enc_hidden_b])
    dec_input = tf.expand_dims([wordtoix[start_token]], 1)

    for t in range(max_len_a):
        predictions, dec_hidden, attention_weights = decoder(dec_input,
                                                             dec_hidden,
                                                             enc_out)

        attention_weights = tf.reshape(attention_weights, (-1, ))
        attention_plot[t] = K.get_value(attention_weights)
        
        predicted_id =  K.get_value(tf.argmax(predictions[0]))       

        if ixtoword[predicted_id] == end_token:
            return result, sentence, attention_plot
        
        result += ixtoword[predicted_id] + ' '
        # the predicted ID is fed back into the model
        dec_input = tf.expand_dims([predicted_id], 1)

    return result, sentence, attention_plot

# %%
def answer(sentence, training=False):
    result, sentence, attention_plot = evaluate(sentence)
    
    if training:
        return result
    
    print('Input: %s' % (sentence))
    print('Predicted answer: {}'.format(result))

# %%
def beam_search(sentence, k=3, maxsample=max_len_a, use_unk=False, oov=None, eos=end_token):
    """return k samples (beams) and their NLL scores, each sample is a sequence of labels,
    all samples starts with an `empty` label and end with `eos` or truncated to length of `maxsample`.
    You need to supply `predict` which returns the label probability of each sample.
    `use_unk` allow usage of `oov` (out-of-vocabulary) label in samples
    """
    
    dead_k = 0 # samples that reached eos
    dead_samples = []
    dead_scores = []
    live_k = 1 # samples that did not yet reached eos
    live_samples = [[wordtoix[start_token]]]
    live_scores = [0]

    sentence = unicode_to_ascii(sentence.lower())
    inputs = [wordtoix[i] for i in sentence.split(' ')]
    inputs = [wordtoix[start_token]]+inputs+[wordtoix[end_token]]
    inputs = pad_sequences([inputs],maxlen=max_len_q, padding='post')

    inputs = tf.convert_to_tensor(inputs)

    hidden = [tf.zeros((1, GRU_units))]
    enc_out, enc_hidden_f, enc_hidden_b = encoder(inputs, hidden)

    dec_hidden = Concatenate(axis=-1)([enc_hidden_f, enc_hidden_b])
    dec_input = tf.expand_dims([wordtoix[start_token]], 0)
        
    while live_k and dead_k < k:
        # for every possible live sample calc prob for every possible label 
        predictions, dec_hidden, _ = decoder(dec_input,dec_hidden,enc_out)
        probs = K.get_value(predictions[0])
        # total score for every sample is sum of -log of word prb
        cand_scores = np.array(live_scores)[:,None] - np.log(probs)
        if not use_unk and oov is not None:
            cand_scores[:,oov] = 1e20
        cand_flat = cand_scores.flatten()

        # find the best (lowest) scores we have from all possible samples and new words
        ranks_flat = cand_flat.argsort()[:(k-dead_k)]
        live_scores = cand_flat[ranks_flat]

        # append the new words to their appropriate live sample
        voc_size = vocab_len
        live_samples = [live_samples[r//voc_size]+[r%voc_size] for r in ranks_flat]

        # live samples that should be dead are...
        zombie = [s[-1] == eos or len(s) >= maxsample for s in live_samples]
        
        # add zombies to the dead
        dead_samples += [s for s,z in zip(live_samples,zombie) if z]  # remove first label == empty
        dead_scores += [s for s,z in zip(live_scores,zombie) if z]
        dead_k = len(dead_samples)
        # remove zombies from the living 
        live_samples = [s for s,z in zip(live_samples,zombie) if not z]
        live_scores = [s for s,z in zip(live_scores,zombie) if not z]
        live_k = len(live_samples)

    final_samples = dead_samples + live_samples
    final_scores = dead_scores + live_scores   
    
    # cutting the strong where end_token is encounterd
    for i in range(len(final_scores)):
        final_scores[i] /= len(final_samples[i]) # normalizing the scores
    
    final_result =[]
    
    for i in range(len(final_scores)):
        final_result.append((final_scores[i],final_samples[i]))
    
    final_list_ix = max(final_result)[1]
    final_list_word = [ixtoword[f] for f in final_list_ix]
    final_sentence = ' '.join(final_list_word[1:])
    end_ix = final_sentence.find(end_token)
    return final_sentence[:end_ix]

# %%
optimizer = tf.keras.optimizers.Adam(init_lr)

def loss_function(real, pred):

    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = K.sparse_categorical_crossentropy(real, pred, from_logits= False)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %%
# checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(snapshot_folder, str(emb_dim)+"-ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
    loss = 0
    with tf.GradientTape() as tape:
        enc_output, enc_hidden_f, enc_hidden_b = encoder(inp, enc_hidden)
        
        dec_hidden = Concatenate(axis=-1)([enc_hidden_f, enc_hidden_b])
        dec_input = tf.expand_dims([wordtoix[start_token]] * batch_size, 1) # dec_input initially == start_token

        # Teacher forcing - feeding the target as the next input
        for t in range(1, targ.shape[1]):
            
            # passing enc_output to the decoder
            predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)
            loss += loss_function(targ[:, t], predictions) # each time just use one timestep output
            # using teacher forcing
            dec_input = tf.expand_dims(targ[:, t], 1) # expected output at this time becomes input for next timestep
            
    batch_loss = (loss / int(targ.shape[1]))
    variables = encoder.trainable_variables + decoder.trainable_variables
    gradients = tape.gradient(loss, variables)
    optimizer.apply_gradients(zip(gradients, variables))
    
    return batch_loss

# %%
history={'loss':[]}
smallest_loss = np.inf
best_ep = 1
EPOCHS = 157
enc_hidden = encoder.initialize_hidden_state()
steps_per_epoch = len(pairs_final_train)//batch_size # used for caculating number of batches
current_ep = 1

# %%
def test_bot(k = 3, beam = False):
    print('#'*20)
    q = 'Hello'
    print('Greedy| Q:',q,'?  A:',answer(q, training=True))
    if beam:print('Beam ',k,'| ',q,'?  A:',beam_search(q,k=k))
    print('%')
    q = 'How are you'
    print('Greedy| Q:',q,'?  A:',answer(q, training=True))
    if beam:print('Beam ',k,'| ',q,'?  A:',beam_search(q,k=k))
    print('%')
    q= 'Are you my friend'
    print('Greedy| Q:',q,'?  A:',answer(q, training=True))
    if beam:print('Beam ',k,'| ',q,'?  A:',beam_search(q,k=k))
    print('%')
    q = 'What are you doing'
    print('Greedy| Q:',q,'?  A:',answer(q, training=True))
    if beam:print('Beam ',k,'| ',q,'?  A:',beam_search(q,k=k))
    print('%')
    q = 'Who are you'
    print('Greedy| Q:',q,'?  A:',answer(q, training=True))
    if beam:print('Beam ',k,'| ',q,'?  A:',beam_search(q,k=k))
    print('%')
    q = 'Do you want to go out'
    print('Greedy| Q:',q,'?  A:',answer(q, training=True))
    if beam:print('Beam ',k,'| ',q,'?  A:',beam_search(q,k=k))
    print('#'*20)

# %%
def plot_history():
    plt.figure(figsize=(4,3))
    plt.plot(best_ep,smallest_loss,'ro')
    plt.plot(history['loss'],'b-')
    plt.legend(['best','loss'])
    plt.show()

# %%
batch_loss = K.constant(0)
X, y = [], []
for ep in range(current_ep,EPOCHS):
    current_ep = ep    
    start = time.time()
    total_loss = 0
    btch = 1

    for p in pairs_final_train:     
        
        question = p[0]
        label = p[1]
        # find the index of each word of the caption in vocabulary
        question_seq = [wordtoix[word] for word in question.split(' ') if word in wordtoix]
        label_seq = [wordtoix[word] for word in label.split(' ') if word in wordtoix]
        # encoder input and decoder input and label
        enc_in_seq = pad_sequences([question_seq], maxlen=max_len_q, padding='post')[0]
        dec_out_seq = pad_sequences([label_seq], maxlen=max_len_a, padding='post')[0]
        
        X.append(enc_in_seq)
        y.append(dec_out_seq)

        if len(X) == batch_size :
            batch_loss = train_step(np.array(X), np.array(y), enc_hidden)
            total_loss += batch_loss
            X , y = [], []
            btch += 1
            if btch % (steps_per_epoch//6) == 0:
                print('Epoch {} Batch {} Loss: {:.4f}'.format(ep , btch, K.get_value(batch_loss)))

    epoch_loss =  K.get_value(total_loss) / steps_per_epoch
    print('\n*** Epoch {} Loss {:.4f} ***\n'.format(ep ,epoch_loss))
    history['loss'].append(epoch_loss)
    
    checkpoint.save(file_prefix = checkpoint_prefix)
#    test_bot(k=5)

    if epoch_loss < smallest_loss:
        smallest_loss = epoch_loss
        best_ep = ep 
        print('check point saved!')
    
    if ep % 3 == 0:
        plot_history()
        
    print('Best epoch so far: ',best_ep,' smallest loss:',smallest_loss)
    print('Time taken for the epoch {:.3f} sec\n'.format(time.time() - start))

    print('=' * 40)
# Out:
# Epoch 10 Batch 2 Loss: 2.3987
# Epoch 10 Batch 3 Loss: 3.5739
# Epoch 10 Batch 4 Loss: 3.3884
# Epoch 10 Batch 5 Loss: 3.6090
# Epoch 10 Batch 6 Loss: 2.5760
# Epoch 10 Batch 7 Loss: 2.9230
# Epoch 10 Batch 8 Loss: 2.2297
# Epoch 10 Batch 9 Loss: 2.5235
#
# *** Epoch 10 Loss 2.9028 ***
#
# check point saved!
# Best epoch so far:  10  smallest loss: 2.902771472930908
# Time taken for the epoch 16.774 sec
#
# ========================================
# Epoch 11 Batch 2 Loss: 3.6844
# Epoch 11 Batch 3 Loss: 2.5757
# Epoch 11 Batch 4 Loss: 3.6615
# Epoch 11 Batch 5 Loss: 3.2399
# Epoch 11 Batch 6 Loss: 3.7276
# Epoch 11 Batch 7 Loss: 2.4252
# Epoch 11 Batch 8 Loss: 2.8708
# Epoch 11 Batch 9 Loss: 1.9782
# Epoch 11 Batch 10 Loss: 2.7222
#
# *** Epoch 11 Loss 3.3607 ***
#
# Best epoch so far:  10  smallest loss: 2.902771472930908
# Time taken for the epoch 18.013 sec
#
# ========================================
# Epoch 12 Batch 2 Loss: 3.9388
# Epoch 12 Batch 3 Loss: 2.5106
# Epoch 12 Batch 4 Loss: 3.7425
# Epoch 12 Batch 5 Loss: 3.0858
# Epoch 12 Batch 6 Loss: 3.6418
# Epoch 12 Batch 7 Loss: 2.3951
# Epoch 12 Batch 8 Loss: 2.9985
# Epoch 12 Batch 9 Loss: 1.9224
# Epoch 12 Batch 10 Loss: 2.8255
#
# *** Epoch 12 Loss 3.3826 ***
# Best epoch so far:  10  smallest loss: 2.902771472930908
# Time taken for the epoch 18.612 sec
#
# ========================================
# Epoch 13 Batch 2 Loss: 3.5549
# Epoch 13 Batch 3 Loss: 2.6792
# Epoch 13 Batch 4 Loss: 3.9624
# Epoch 13 Batch 5 Loss: 2.9490
# Epoch 13 Batch 6 Loss: 3.6148
# Epoch 13 Batch 7 Loss: 2.4146
# Epoch 13 Batch 8 Loss: 2.9841
# Epoch 13 Batch 9 Loss: 1.9645
# Epoch 13 Batch 10 Loss: 2.7058
#
# *** Epoch 13 Loss 3.3537 ***
#
# Best epoch so far:  10  smallest loss: 2.902771472930908
# Time taken for the epoch 18.921 sec
#
# ========================================
# Epoch 14 Batch 2 Loss: 3.5223
# Epoch 14 Batch 3 Loss: 2.6824
# Epoch 14 Batch 4 Loss: 3.9533
# Epoch 14 Batch 5 Loss: 3.1933
# Epoch 14 Batch 6 Loss: 3.3698
# Epoch 14 Batch 7 Loss: 2.3714
# Epoch 14 Batch 8 Loss: 3.0131
# Epoch 14 Batch 9 Loss: 2.0594
# Epoch 14 Batch 10 Loss: 2.8751
#
# *** Epoch 14 Loss 3.3800 ***
#
# Best epoch so far:  10  smallest loss: 2.902771472930908
# Time taken for the epoch 18.458 sec
#
# ========================================
# Epoch 15 Batch 2 Loss: 3.3617
# Epoch 15 Batch 3 Loss: 2.7313
# Epoch 15 Batch 4 Loss: 3.7558
# Epoch 15 Batch 5 Loss: 3.4774
# Epoch 15 Batch 6 Loss: 3.0746
# Epoch 15 Batch 7 Loss: 2.7228
# Epoch 15 Batch 8 Loss: 2.7806
# Epoch 15 Batch 9 Loss: 2.0861
# Epoch 15 Batch 10 Loss: 3.1517
#
# *** Epoch 15 Loss 3.3927 ***
# Best epoch so far:  10  smallest loss: 2.902771472930908
# Time taken for the epoch 18.470 sec
#
# ========================================
# Epoch 16 Batch 2 Loss: 3.1088
# Epoch 16 Batch 3 Loss: 2.7996
# Epoch 16 Batch 4 Loss: 3.7065
# Epoch 16 Batch 5 Loss: 3.4675
# Epoch 16 Batch 6 Loss: 2.8629
# Epoch 16 Batch 7 Loss: 2.9414
# Epoch 16 Batch 8 Loss: 2.6471
# Epoch 16 Batch 9 Loss: 2.2893
# Epoch 16 Batch 10 Loss: 3.2286
#
# *** Epoch 16 Loss 3.3815 ***
#
# Best epoch so far:  10  smallest loss: 2.902771472930908
# Time taken for the epoch 18.583 sec
#
# ========================================
# Epoch 17 Batch 2 Loss: 2.6919
# Epoch 17 Batch 3 Loss: 3.2545
# Epoch 17 Batch 4 Loss: 3.6444
# Epoch 17 Batch 5 Loss: 3.2325
# Epoch 17 Batch 6 Loss: 2.8637
# Epoch 17 Batch 7 Loss: 2.9067
# Epoch 17 Batch 8 Loss: 2.4444
# Epoch 17 Batch 9 Loss: 2.3269
# Epoch 17 Batch 10 Loss: 3.5680
#
# *** Epoch 17 Loss 3.3666 ***
#
# Best epoch so far:  10  smallest loss: 2.902771472930908
# Time taken for the epoch 17.604 sec
#
# ========================================
# Epoch 18 Batch 2 Loss: 2.3915
# Epoch 18 Batch 3 Loss: 3.5614
# Epoch 18 Batch 4 Loss: 3.3760
# Epoch 18 Batch 5 Loss: 3.5912
# Epoch 18 Batch 6 Loss: 2.5636
# Epoch 18 Batch 7 Loss: 2.9054
# Epoch 18 Batch 8 Loss: 2.1876
# Epoch 18 Batch 9 Loss: 2.4731
#
# *** Epoch 18 Loss 2.8812 ***
#
# check point saved!
# Best epoch so far:  18  smallest loss: 2.8812363147735596
# Time taken for the epoch 16.071 sec
#
# ========================================
# Epoch 19 Batch 2 Loss: 3.6141
# Epoch 19 Batch 3 Loss: 2.5658
# Epoch 19 Batch 4 Loss: 3.6349
# Epoch 19 Batch 5 Loss: 3.2203
# Epoch 19 Batch 6 Loss: 3.7025
# Epoch 19 Batch 7 Loss: 2.4123
# Epoch 19 Batch 8 Loss: 2.8519
# Epoch 19 Batch 9 Loss: 1.9381
# Epoch 19 Batch 10 Loss: 2.6678
#
# *** Epoch 19 Loss 3.3260 ***
#
# Best epoch so far:  18  smallest loss: 2.8812363147735596
# Time taken for the epoch 19.405 sec
#
# ========================================
# Epoch 20 Batch 2 Loss: 3.8751
# Epoch 20 Batch 3 Loss: 2.4869
# Epoch 20 Batch 4 Loss: 3.6972
# Epoch 20 Batch 5 Loss: 3.0490
# Epoch 20 Batch 6 Loss: 3.6013
# Epoch 20 Batch 7 Loss: 2.3683
# Epoch 20 Batch 8 Loss: 2.9613
# Epoch 20 Batch 9 Loss: 1.8820
# Epoch 20 Batch 10 Loss: 2.7728
#
# *** Epoch 20 Loss 3.3368 ***
#
# Best epoch so far:  18  smallest loss: 2.8812363147735596
# Time taken for the epoch 19.184 sec
#
# ========================================
# Epoch 21 Batch 2 Loss: 3.5020
# Epoch 21 Batch 3 Loss: 2.6408
# Epoch 21 Batch 4 Loss: 3.8904
# Epoch 21 Batch 5 Loss: 2.8984
# Epoch 21 Batch 6 Loss: 3.5549
# Epoch 21 Batch 7 Loss: 2.3772
# Epoch 21 Batch 8 Loss: 2.9330
# Epoch 21 Batch 9 Loss: 1.9195
# Epoch 21 Batch 10 Loss: 2.6509
#
# *** Epoch 21 Loss 3.2959 ***
# Best epoch so far:  18  smallest loss: 2.8812363147735596
# Time taken for the epoch 18.762 sec
#
# ========================================
# Epoch 22 Batch 2 Loss: 3.4663
# Epoch 22 Batch 3 Loss: 2.6357
# Epoch 22 Batch 4 Loss: 3.8599
# Epoch 22 Batch 5 Loss: 3.1268
# Epoch 22 Batch 6 Loss: 3.2904
# Epoch 22 Batch 7 Loss: 2.3279
# Epoch 22 Batch 8 Loss: 2.9478
# Epoch 22 Batch 9 Loss: 2.0087
# Epoch 22 Batch 10 Loss: 2.8102
#
# *** Epoch 22 Loss 3.3092 ***
#
# Best epoch so far:  18  smallest loss: 2.8812363147735596
# Time taken for the epoch 19.514 sec
#
# ========================================
# Epoch 23 Batch 2 Loss: 3.2975
# Epoch 23 Batch 3 Loss: 2.6760
# Epoch 23 Batch 4 Loss: 3.6536
# Epoch 23 Batch 5 Loss: 3.3916
# Epoch 23 Batch 6 Loss: 2.9873
# Epoch 23 Batch 7 Loss: 2.6612
# Epoch 23 Batch 8 Loss: 2.7107
# Epoch 23 Batch 9 Loss: 2.0349
# Epoch 23 Batch 10 Loss: 3.0745
#
# *** Epoch 23 Loss 3.3109 ***
#
# Best epoch so far:  18  smallest loss: 2.8812363147735596
# Time taken for the epoch 17.409 sec
#
# ========================================
# Epoch 24 Batch 2 Loss: 3.0350
# Epoch 24 Batch 3 Loss: 2.7314
# Epoch 24 Batch 4 Loss: 3.5928
# Epoch 24 Batch 5 Loss: 3.3729
# Epoch 24 Batch 6 Loss: 2.7723
# Epoch 24 Batch 7 Loss: 2.8631
# Epoch 24 Batch 8 Loss: 2.5674
# Epoch 24 Batch 9 Loss: 2.2354
# Epoch 24 Batch 10 Loss: 3.1475
#
# *** Epoch 24 Loss 3.2897 ***
# Best epoch so far:  18  smallest loss: 2.8812363147735596
# Time taken for the epoch 17.785 sec
#
# ========================================
# Epoch 25 Batch 2 Loss: 2.6211
# Epoch 25 Batch 3 Loss: 3.1579
# Epoch 25 Batch 4 Loss: 3.5120
# Epoch 25 Batch 5 Loss: 3.1383
# Epoch 25 Batch 6 Loss: 2.7697
# Epoch 25 Batch 7 Loss: 2.8274
# Epoch 25 Batch 8 Loss: 2.3538
# Epoch 25 Batch 9 Loss: 2.2584
# Epoch 25 Batch 10 Loss: 3.4615
#
# *** Epoch 25 Loss 3.2625 ***
#
# Best epoch so far:  18  smallest loss: 2.8812363147735596
# Time taken for the epoch 17.731 sec
#
# ========================================
# Epoch 26 Batch 2 Loss: 2.3311
# Epoch 26 Batch 3 Loss: 3.4433
# Epoch 26 Batch 4 Loss: 3.2355
# Epoch 26 Batch 5 Loss: 3.4674
# Epoch 26 Batch 6 Loss: 2.4728
# Epoch 26 Batch 7 Loss: 2.8168
# Epoch 26 Batch 8 Loss: 2.1048
# Epoch 26 Batch 9 Loss: 2.3910
#
# *** Epoch 26 Loss 2.7828 ***
#
# check point saved!
# Best epoch so far:  26  smallest loss: 2.782825469970703
# Time taken for the epoch 15.858 sec
#
# ========================================
# Epoch 27 Batch 2 Loss: 3.4902
# Epoch 27 Batch 3 Loss: 2.4894
# Epoch 27 Batch 4 Loss: 3.4895
# Epoch 27 Batch 5 Loss: 3.0789
# Epoch 27 Batch 6 Loss: 3.5602
# Epoch 27 Batch 7 Loss: 2.3306
# Epoch 27 Batch 8 Loss: 2.7515
# Epoch 27 Batch 9 Loss: 1.8583
# Epoch 27 Batch 10 Loss: 2.5751
#
# *** Epoch 27 Loss 3.2030 ***
# Best epoch so far:  26  smallest loss: 2.782825469970703
# Time taken for the epoch 17.451 sec
#
# ========================================
# Epoch 28 Batch 2 Loss: 3.7392
# Epoch 28 Batch 3 Loss: 2.4065
# Epoch 28 Batch 4 Loss: 3.5207
# Epoch 28 Batch 5 Loss: 2.9214
# Epoch 28 Batch 6 Loss: 3.4493
# Epoch 28 Batch 7 Loss: 2.2891
# Epoch 28 Batch 8 Loss: 2.8563
# Epoch 28 Batch 9 Loss: 1.8029
# Epoch 28 Batch 10 Loss: 2.6801
#
# *** Epoch 28 Loss 3.2082 ***
#
# Best epoch so far:  26  smallest loss: 2.782825469970703
# Time taken for the epoch 17.386 sec
#
# ========================================
# Epoch 29 Batch 2 Loss: 3.3705
# Epoch 29 Batch 3 Loss: 2.5550
# Epoch 29 Batch 4 Loss: 3.6920
# Epoch 29 Batch 5 Loss: 2.7779
# Epoch 29 Batch 6 Loss: 3.3979
# Epoch 29 Batch 7 Loss: 2.3012
# Epoch 29 Batch 8 Loss: 2.8246
# Epoch 29 Batch 9 Loss: 1.8416
# Epoch 29 Batch 10 Loss: 2.5605
#
# *** Epoch 29 Loss 3.1651 ***
#
# Best epoch so far:  26  smallest loss: 2.782825469970703
# Time taken for the epoch 18.124 sec
#
# ========================================
# Epoch 30 Batch 2 Loss: 3.3283
# Epoch 30 Batch 3 Loss: 2.5481
# Epoch 30 Batch 4 Loss: 3.6612
# Epoch 30 Batch 5 Loss: 3.0004
# Epoch 30 Batch 6 Loss: 3.1353
# Epoch 30 Batch 7 Loss: 2.2536
# Epoch 30 Batch 8 Loss: 2.8339
# Epoch 30 Batch 9 Loss: 1.9332
# Epoch 30 Batch 10 Loss: 2.7177
#
# *** Epoch 30 Loss 3.1765 ***
# Best epoch so far:  26  smallest loss: 2.782825469970703
# Time taken for the epoch 18.092 sec
#
# ========================================
# Epoch 31 Batch 2 Loss: 3.1520
# Epoch 31 Batch 3 Loss: 2.5851
# Epoch 31 Batch 4 Loss: 3.4577
# Epoch 31 Batch 5 Loss: 3.2569
# Epoch 31 Batch 6 Loss: 2.8474
# Epoch 31 Batch 7 Loss: 2.5690
# Epoch 31 Batch 8 Loss: 2.5990
# Epoch 31 Batch 9 Loss: 1.9589
# Epoch 31 Batch 10 Loss: 2.9645
#
# *** Epoch 31 Loss 3.1738 ***
#
# Best epoch so far:  26  smallest loss: 2.782825469970703
# Time taken for the epoch 18.604 sec
#
# ========================================
# Epoch 32 Batch 2 Loss: 2.9045
# Epoch 32 Batch 3 Loss: 2.6293
# Epoch 32 Batch 4 Loss: 3.4003
# Epoch 32 Batch 5 Loss: 3.2408
# Epoch 32 Batch 6 Loss: 2.6391
# Epoch 32 Batch 7 Loss: 2.7681
# Epoch 32 Batch 8 Loss: 2.4556
# Epoch 32 Batch 9 Loss: 2.1489
# Epoch 32 Batch 10 Loss: 3.0174
#
# *** Epoch 32 Loss 3.1505 ***
#
# Best epoch so far:  26  smallest loss: 2.782825469970703
# Time taken for the epoch 18.477 sec
#
# ========================================
# Epoch 33 Batch 2 Loss: 2.5199
# Epoch 33 Batch 3 Loss: 3.0282
# Epoch 33 Batch 4 Loss: 3.3361
# Epoch 33 Batch 5 Loss: 3.0188
# Epoch 33 Batch 6 Loss: 2.6305
# Epoch 33 Batch 7 Loss: 2.7342
# Epoch 33 Batch 8 Loss: 2.2602
# Epoch 33 Batch 9 Loss: 2.1793
# Epoch 33 Batch 10 Loss: 3.3049
#
# *** Epoch 33 Loss 3.1265 ***
# Best epoch so far:  26  smallest loss: 2.782825469970703
# Time taken for the epoch 19.237 sec
#
# ========================================
# Epoch 34 Batch 2 Loss: 2.2548
# Epoch 34 Batch 3 Loss: 3.2997
# Epoch 34 Batch 4 Loss: 3.0806
# Epoch 34 Batch 5 Loss: 3.3283
# Epoch 34 Batch 6 Loss: 2.3670
# Epoch 34 Batch 7 Loss: 2.7207
# Epoch 34 Batch 8 Loss: 2.0251
# Epoch 34 Batch 9 Loss: 2.3119
#
# *** Epoch 34 Loss 2.6735 ***
#
# check point saved!
# Best epoch so far:  34  smallest loss: 2.6735174655914307
# Time taken for the epoch 16.117 sec
#
# ========================================
# Epoch 35 Batch 2 Loss: 3.3416
# Epoch 35 Batch 3 Loss: 2.4100
# Epoch 35 Batch 4 Loss: 3.3389
# Epoch 35 Batch 5 Loss: 2.9478
# Epoch 35 Batch 6 Loss: 3.4166
# Epoch 35 Batch 7 Loss: 2.2534
# Epoch 35 Batch 8 Loss: 2.6608
# Epoch 35 Batch 9 Loss: 1.7902
# Epoch 35 Batch 10 Loss: 2.4886
#
# *** Epoch 35 Loss 3.0810 ***
#
# Best epoch so far:  34  smallest loss: 2.6735174655914307
# Time taken for the epoch 18.515 sec
#
# ========================================
# Epoch 36 Batch 2 Loss: 3.5928
# Epoch 36 Batch 3 Loss: 2.3331
# Epoch 36 Batch 4 Loss: 3.3571
# Epoch 36 Batch 5 Loss: 2.8189
# Epoch 36 Batch 6 Loss: 3.3184
# Epoch 36 Batch 7 Loss: 2.2151
# Epoch 36 Batch 8 Loss: 2.7647
# Epoch 36 Batch 9 Loss: 1.7374
# Epoch 36 Batch 10 Loss: 2.5923
#
# *** Epoch 36 Loss 3.0912 ***
# Best epoch so far:  34  smallest loss: 2.6735174655914307
# Time taken for the epoch 18.775 sec
#
# ========================================
# Epoch 37 Batch 2 Loss: 3.2413
# Epoch 37 Batch 3 Loss: 2.4805
# Epoch 37 Batch 4 Loss: 3.5195
# Epoch 37 Batch 5 Loss: 2.6947
# Epoch 37 Batch 6 Loss: 3.2719
# Epoch 37 Batch 7 Loss: 2.2346
# Epoch 37 Batch 8 Loss: 2.7323
# Epoch 37 Batch 9 Loss: 1.7785
# Epoch 37 Batch 10 Loss: 2.4744
#
# *** Epoch 37 Loss 3.0535 ***
#
# Best epoch so far:  34  smallest loss: 2.6735174655914307
# Time taken for the epoch 17.996 sec
#
# ========================================
# Epoch 38 Batch 2 Loss: 3.2032
# Epoch 38 Batch 3 Loss: 2.4748
# Epoch 38 Batch 4 Loss: 3.5037
# Epoch 38 Batch 5 Loss: 2.9133
# Epoch 38 Batch 6 Loss: 3.0139
# Epoch 38 Batch 7 Loss: 2.1982
# Epoch 38 Batch 8 Loss: 2.7423
# Epoch 38 Batch 9 Loss: 1.8742
# Epoch 38 Batch 10 Loss: 2.6313
#
# *** Epoch 38 Loss 3.0694 ***
#
# Best epoch so far:  34  smallest loss: 2.6735174655914307
# Time taken for the epoch 17.206 sec
#
# ========================================
# Epoch 39 Batch 2 Loss: 3.0331
# Epoch 39 Batch 3 Loss: 2.5144
# Epoch 39 Batch 4 Loss: 3.3146
# Epoch 39 Batch 5 Loss: 3.1654
# Epoch 39 Batch 6 Loss: 2.7412
# Epoch 39 Batch 7 Loss: 2.4988
# Epoch 39 Batch 8 Loss: 2.5135
# Epoch 39 Batch 9 Loss: 1.9068
# Epoch 39 Batch 10 Loss: 2.8740
#
# *** Epoch 39 Loss 3.0702 ***
# Best epoch so far:  34  smallest loss: 2.6735174655914307
# Time taken for the epoch 17.960 sec
#
# ========================================
# Epoch 40 Batch 2 Loss: 2.8028
# Epoch 40 Batch 3 Loss: 2.5517
# Epoch 40 Batch 4 Loss: 3.2646
# Epoch 40 Batch 5 Loss: 3.1497
# Epoch 40 Batch 6 Loss: 2.5434
# Epoch 40 Batch 7 Loss: 2.6892
# Epoch 40 Batch 8 Loss: 2.3764
# Epoch 40 Batch 9 Loss: 2.0910
# Epoch 40 Batch 10 Loss: 2.9244
#
# *** Epoch 40 Loss 3.0492 ***
#
# Best epoch so far:  34  smallest loss: 2.6735174655914307
# Time taken for the epoch 18.039 sec
#
# ========================================
# Epoch 41 Batch 2 Loss: 2.4415
# Epoch 41 Batch 3 Loss: 2.9296
# Epoch 41 Batch 4 Loss: 3.2136
# Epoch 41 Batch 5 Loss: 2.9318
# Epoch 41 Batch 6 Loss: 2.5392
# Epoch 41 Batch 7 Loss: 2.6577
# Epoch 41 Batch 8 Loss: 2.1854
# Epoch 41 Batch 9 Loss: 2.1186
# Epoch 41 Batch 10 Loss: 3.1983
#
# *** Epoch 41 Loss 3.0270 ***
#
# Best epoch so far:  34  smallest loss: 2.6735174655914307
# Time taken for the epoch 17.801 sec
#
# ========================================
# Epoch 42 Batch 2 Loss: 2.1946
# Epoch 42 Batch 3 Loss: 3.1950
# Epoch 42 Batch 4 Loss: 2.9704
# Epoch 42 Batch 5 Loss: 3.2250
# Epoch 42 Batch 6 Loss: 2.2902
# Epoch 42 Batch 7 Loss: 2.6458
# Epoch 42 Batch 8 Loss: 1.9587
# Epoch 42 Batch 9 Loss: 2.2434
#
# *** Epoch 42 Loss 2.5904 ***
#
# check point saved!
# Best epoch so far:  42  smallest loss: 2.5903825759887695
# Time taken for the epoch 15.612 sec
#
# ========================================
# Epoch 43 Batch 2 Loss: 3.2357
# Epoch 43 Batch 3 Loss: 2.3468
# Epoch 43 Batch 4 Loss: 3.2306
# Epoch 43 Batch 5 Loss: 2.8491
# Epoch 43 Batch 6 Loss: 3.3023
# Epoch 43 Batch 7 Loss: 2.1901
# Epoch 43 Batch 8 Loss: 2.5859
# Epoch 43 Batch 9 Loss: 1.7335
# Epoch 43 Batch 10 Loss: 2.4124
#
# *** Epoch 43 Loss 2.9858 ***
#
# Best epoch so far:  42  smallest loss: 2.5903825759887695
# Time taken for the epoch 18.952 sec
#
# ========================================
# Epoch 44 Batch 2 Loss: 3.4750
# Epoch 44 Batch 3 Loss: 2.2768
# Epoch 44 Batch 4 Loss: 3.2418
# Epoch 44 Batch 5 Loss: 2.7373
# Epoch 44 Batch 6 Loss: 3.2047
# Epoch 44 Batch 7 Loss: 2.1503
# Epoch 44 Batch 8 Loss: 2.6862
# Epoch 44 Batch 9 Loss: 1.6870
# Epoch 44 Batch 10 Loss: 2.5180
#
# *** Epoch 44 Loss 2.9971 ***
#
# Best epoch so far:  42  smallest loss: 2.5903825759887695
# Time taken for the epoch 17.854 sec
#
# ========================================
# Epoch 45 Batch 2 Loss: 3.1326
# Epoch 45 Batch 3 Loss: 2.4208
# Epoch 45 Batch 4 Loss: 3.3928
# Epoch 45 Batch 5 Loss: 2.6259
# Epoch 45 Batch 6 Loss: 3.1644
# Epoch 45 Batch 7 Loss: 2.1675
# Epoch 45 Batch 8 Loss: 2.6451
# Epoch 45 Batch 9 Loss: 1.7291
# Epoch 45 Batch 10 Loss: 2.4055
#
# *** Epoch 45 Loss 2.9604 ***
# Best epoch so far:  42  smallest loss: 2.5903825759887695
# Time taken for the epoch 16.530 sec
#
# ========================================
# Epoch 46 Batch 2 Loss: 3.1025
# Epoch 46 Batch 3 Loss: 2.4135
# Epoch 46 Batch 4 Loss: 3.3767
# Epoch 46 Batch 5 Loss: 2.8422
# Epoch 46 Batch 6 Loss: 2.9099
# Epoch 46 Batch 7 Loss: 2.1418
# Epoch 46 Batch 8 Loss: 2.6510
# Epoch 46 Batch 9 Loss: 1.8175
# Epoch 46 Batch 10 Loss: 2.5570
#
# *** Epoch 46 Loss 2.9765 ***
#
# Best epoch so far:  42  smallest loss: 2.5903825759887695
# Time taken for the epoch 17.495 sec
#
# ========================================
# Epoch 47 Batch 2 Loss: 2.9393
# Epoch 47 Batch 3 Loss: 2.4548
# Epoch 47 Batch 4 Loss: 3.1920
# Epoch 47 Batch 5 Loss: 3.0846
# Epoch 47 Batch 6 Loss: 2.6465
# Epoch 47 Batch 7 Loss: 2.4336
# Epoch 47 Batch 8 Loss: 2.4307
# Epoch 47 Batch 9 Loss: 1.8502
# Epoch 47 Batch 10 Loss: 2.7900
#
# *** Epoch 47 Loss 2.9777 ***
#
# Best epoch so far:  42  smallest loss: 2.5903825759887695
# Time taken for the epoch 16.591 sec
#
# ========================================
# Epoch 48 Batch 2 Loss: 2.7175
# Epoch 48 Batch 3 Loss: 2.4884
# Epoch 48 Batch 4 Loss: 3.1522
# Epoch 48 Batch 5 Loss: 3.0650
# Epoch 48 Batch 6 Loss: 2.4523
# Epoch 48 Batch 7 Loss: 2.6165
# Epoch 48 Batch 8 Loss: 2.3025
# Epoch 48 Batch 9 Loss: 2.0350
# Epoch 48 Batch 10 Loss: 2.8342
#
# *** Epoch 48 Loss 2.9579 ***
# Best epoch so far:  42  smallest loss: 2.5903825759887695
# Time taken for the epoch 16.400 sec
#
# ========================================
# Epoch 49 Batch 2 Loss: 2.3689
# Epoch 49 Batch 3 Loss: 2.8501
# Epoch 49 Batch 4 Loss: 3.1130
# Epoch 49 Batch 5 Loss: 2.8515
# Epoch 49 Batch 6 Loss: 2.4484
# Epoch 49 Batch 7 Loss: 2.5850
# Epoch 49 Batch 8 Loss: 2.1194
# Epoch 49 Batch 9 Loss: 2.0679
# Epoch 49 Batch 10 Loss: 3.0981
#
# *** Epoch 49 Loss 2.9378 ***
#
# Best epoch so far:  42  smallest loss: 2.5903825759887695
# Time taken for the epoch 16.507 sec
#
# ========================================
# Epoch 50 Batch 2 Loss: 2.1350
# Epoch 50 Batch 3 Loss: 3.1064
# Epoch 50 Batch 4 Loss: 2.8777
# Epoch 50 Batch 5 Loss: 3.1302
# Epoch 50 Batch 6 Loss: 2.2145
# Epoch 50 Batch 7 Loss: 2.5761
# Epoch 50 Batch 8 Loss: 1.9009
# Epoch 50 Batch 9 Loss: 2.1948
#
# *** Epoch 50 Loss 2.5170 ***
#
# check point saved!
# Best epoch so far:  50  smallest loss: 2.516953229904175
# Time taken for the epoch 20.634 sec
#
# ========================================
# Epoch 51 Batch 2 Loss: 3.1430
# Epoch 51 Batch 3 Loss: 2.2816
# Epoch 51 Batch 4 Loss: 3.1327
# Epoch 51 Batch 5 Loss: 2.7708
# Epoch 51 Batch 6 Loss: 3.2061
# Epoch 51 Batch 7 Loss: 2.1264
# Epoch 51 Batch 8 Loss: 2.5162
# Epoch 51 Batch 9 Loss: 1.6826
# Epoch 51 Batch 10 Loss: 2.3638
#
# *** Epoch 51 Loss 2.9029 ***
# Best epoch so far:  50  smallest loss: 2.516953229904175
# Time taken for the epoch 22.349 sec
#
# ========================================
# Epoch 52 Batch 2 Loss: 3.3832
# Epoch 52 Batch 3 Loss: 2.2201
# Epoch 52 Batch 4 Loss: 3.1285
# Epoch 52 Batch 5 Loss: 2.6737
# Epoch 52 Batch 6 Loss: 3.1212
# Epoch 52 Batch 7 Loss: 2.0926
# Epoch 52 Batch 8 Loss: 2.6142
# Epoch 52 Batch 9 Loss: 1.6397
# Epoch 52 Batch 10 Loss: 2.4663
#
# *** Epoch 52 Loss 2.9174 ***
#
# Best epoch so far:  50  smallest loss: 2.516953229904175
# Time taken for the epoch 22.635 sec
#
# ========================================
# Epoch 53 Batch 2 Loss: 3.0500
# Epoch 53 Batch 3 Loss: 2.3701
# Epoch 53 Batch 4 Loss: 3.2769
# Epoch 53 Batch 5 Loss: 2.5651
# Epoch 53 Batch 6 Loss: 3.0771
# Epoch 53 Batch 7 Loss: 2.1167
# Epoch 53 Batch 8 Loss: 2.5881
# Epoch 53 Batch 9 Loss: 1.6892
# Epoch 53 Batch 10 Loss: 2.3459
#
# *** Epoch 53 Loss 2.8849 ***
#
# Best epoch so far:  50  smallest loss: 2.516953229904175
# Time taken for the epoch 22.326 sec
#
# ========================================
# Epoch 54 Batch 2 Loss: 3.0220
# Epoch 54 Batch 3 Loss: 2.3627
# Epoch 54 Batch 4 Loss: 3.2757
# Epoch 54 Batch 5 Loss: 2.7961
# Epoch 54 Batch 6 Loss: 2.8071
# Epoch 54 Batch 7 Loss: 2.0953
# Epoch 54 Batch 8 Loss: 2.5880
# Epoch 54 Batch 9 Loss: 1.7737
# Epoch 54 Batch 10 Loss: 2.5007
#
# *** Epoch 54 Loss 2.9027 ***
# Best epoch so far:  50  smallest loss: 2.516953229904175
# Time taken for the epoch 22.867 sec
#
# ========================================
# Epoch 55 Batch 2 Loss: 2.8825
# Epoch 55 Batch 3 Loss: 2.4015
# Epoch 55 Batch 4 Loss: 3.0958
# Epoch 55 Batch 5 Loss: 3.0196
# Epoch 55 Batch 6 Loss: 2.5600
# Epoch 55 Batch 7 Loss: 2.4086
# Epoch 55 Batch 8 Loss: 2.3842
# Epoch 55 Batch 9 Loss: 1.7970
# Epoch 55 Batch 10 Loss: 2.7142
#
# *** Epoch 55 Loss 2.9079 ***
#
# Best epoch so far:  50  smallest loss: 2.516953229904175
# Time taken for the epoch 22.547 sec
#
# ========================================
# Epoch 56 Batch 2 Loss: 2.6552
# Epoch 56 Batch 3 Loss: 2.4479
# Epoch 56 Batch 4 Loss: 3.0919
# Epoch 56 Batch 5 Loss: 2.9820
# Epoch 56 Batch 6 Loss: 2.3654
# Epoch 56 Batch 7 Loss: 2.5840
# Epoch 56 Batch 8 Loss: 2.2781
# Epoch 56 Batch 9 Loss: 2.0014
# Epoch 56 Batch 10 Loss: 2.7560
#
# *** Epoch 56 Loss 2.8952 ***
#
# Best epoch so far:  50  smallest loss: 2.516953229904175
# Time taken for the epoch 21.698 sec
#
# ========================================
# Epoch 57 Batch 2 Loss: 2.2978
# Epoch 57 Batch 3 Loss: 2.7915
# Epoch 57 Batch 4 Loss: 3.0474
# Epoch 57 Batch 5 Loss: 2.7851
# Epoch 57 Batch 6 Loss: 2.3725
# Epoch 57 Batch 7 Loss: 2.5268
# Epoch 57 Batch 8 Loss: 2.0636
# Epoch 57 Batch 9 Loss: 2.0214
# Epoch 57 Batch 10 Loss: 3.0091
#
# *** Epoch 57 Loss 2.8644 ***
# Best epoch so far:  50  smallest loss: 2.516953229904175
# Time taken for the epoch 21.879 sec
#
# ========================================
# Epoch 58 Batch 2 Loss: 2.0813
# Epoch 58 Batch 3 Loss: 3.0184
# Epoch 58 Batch 4 Loss: 2.7837
# Epoch 58 Batch 5 Loss: 3.0386
# Epoch 58 Batch 6 Loss: 2.1448
# Epoch 58 Batch 7 Loss: 2.5131
# Epoch 58 Batch 8 Loss: 1.8353
# Epoch 58 Batch 9 Loss: 2.1153
#
# *** Epoch 58 Loss 2.4413 ***
#
# check point saved!
# Best epoch so far:  58  smallest loss: 2.4413001537323
# Time taken for the epoch 19.805 sec
#
# ========================================
# Epoch 59 Batch 2 Loss: 3.0320
# Epoch 59 Batch 3 Loss: 2.2183
# Epoch 59 Batch 4 Loss: 3.0368
# Epoch 59 Batch 5 Loss: 2.6731
# Epoch 59 Batch 6 Loss: 3.0874
# Epoch 59 Batch 7 Loss: 2.0619
# Epoch 59 Batch 8 Loss: 2.4535
# Epoch 59 Batch 9 Loss: 1.6225
# Epoch 59 Batch 10 Loss: 2.2700
#
# *** Epoch 59 Loss 2.8069 ***
#
# Best epoch so far:  58  smallest loss: 2.4413001537323
# Time taken for the epoch 21.879 sec
#
# ========================================
# Epoch 60 Batch 2 Loss: 3.2511
# Epoch 60 Batch 3 Loss: 2.1556
# Epoch 60 Batch 4 Loss: 3.0267
# Epoch 60 Batch 5 Loss: 2.5755
# Epoch 60 Batch 6 Loss: 2.9939
# Epoch 60 Batch 7 Loss: 2.0244
# Epoch 60 Batch 8 Loss: 2.5417
# Epoch 60 Batch 9 Loss: 1.5860
# Epoch 60 Batch 10 Loss: 2.3721
#
# *** Epoch 60 Loss 2.8159 ***
# Best epoch so far:  58  smallest loss: 2.4413001537323
# Time taken for the epoch 22.231 sec
#
# ========================================
# Epoch 61 Batch 2 Loss: 2.9230
# Epoch 61 Batch 3 Loss: 2.2953
# Epoch 61 Batch 4 Loss: 3.1558
# Epoch 61 Batch 5 Loss: 2.4735
# Epoch 61 Batch 6 Loss: 2.9574
# Epoch 61 Batch 7 Loss: 2.0417
# Epoch 61 Batch 8 Loss: 2.4888
# Epoch 61 Batch 9 Loss: 1.6315
# Epoch 61 Batch 10 Loss: 2.2585
#
# *** Epoch 61 Loss 2.7782 ***
#
# Best epoch so far:  58  smallest loss: 2.4413001537323
# Time taken for the epoch 21.841 sec
#
# ========================================
# Epoch 62 Batch 2 Loss: 2.8990
# Epoch 62 Batch 3 Loss: 2.2849
# Epoch 62 Batch 4 Loss: 3.1386
# Epoch 62 Batch 5 Loss: 2.6770
# Epoch 62 Batch 6 Loss: 2.6952
# Epoch 62 Batch 7 Loss: 2.0330
# Epoch 62 Batch 8 Loss: 2.4902
# Epoch 62 Batch 9 Loss: 1.7132
# Epoch 62 Batch 10 Loss: 2.3970
#
# *** Epoch 62 Loss 2.7910 ***
#
# Best epoch so far:  58  smallest loss: 2.4413001537323
# Time taken for the epoch 21.818 sec
#
# ========================================
# Epoch 63 Batch 2 Loss: 2.7465
# Epoch 63 Batch 3 Loss: 2.3198
# Epoch 63 Batch 4 Loss: 2.9640
# Epoch 63 Batch 5 Loss: 2.8971
# Epoch 63 Batch 6 Loss: 2.4454
# Epoch 63 Batch 7 Loss: 2.3037
# Epoch 63 Batch 8 Loss: 2.2793
# Epoch 63 Batch 9 Loss: 1.7398
# Epoch 63 Batch 10 Loss: 2.6172
#
# *** Epoch 63 Loss 2.7891 ***
# Best epoch so far:  58  smallest loss: 2.4413001537323
# Time taken for the epoch 21.673 sec
#
# ========================================
# Epoch 64 Batch 2 Loss: 2.5366
# Epoch 64 Batch 3 Loss: 2.3402
# Epoch 64 Batch 4 Loss: 2.9238
# Epoch 64 Batch 5 Loss: 2.8770
# Epoch 64 Batch 6 Loss: 2.2648
# Epoch 64 Batch 7 Loss: 2.4717
# Epoch 64 Batch 8 Loss: 2.1546
# Epoch 64 Batch 9 Loss: 1.9092
# Epoch 64 Batch 10 Loss: 2.6497
#
# *** Epoch 64 Loss 2.7660 ***
#
# Best epoch so far:  58  smallest loss: 2.4413001537323
# Time taken for the epoch 21.273 sec
#
# ========================================
# Epoch 65 Batch 2 Loss: 2.2156
# Epoch 65 Batch 3 Loss: 2.6705
# Epoch 65 Batch 4 Loss: 2.8889
# Epoch 65 Batch 5 Loss: 2.6665
# Epoch 65 Batch 6 Loss: 2.2640
# Epoch 65 Batch 7 Loss: 2.4401
# Epoch 65 Batch 8 Loss: 1.9807
# Epoch 65 Batch 9 Loss: 1.9341
# Epoch 65 Batch 10 Loss: 2.8746
#
# *** Epoch 65 Loss 2.7419 ***
#
# Best epoch so far:  58  smallest loss: 2.4413001537323
# Time taken for the epoch 20.149 sec
#
# ========================================
# Epoch 66 Batch 2 Loss: 2.0095
# Epoch 66 Batch 3 Loss: 2.9082
# Epoch 66 Batch 4 Loss: 2.6658
# Epoch 66 Batch 5 Loss: 2.9088
# Epoch 66 Batch 6 Loss: 2.0560
# Epoch 66 Batch 7 Loss: 2.4307
# Epoch 66 Batch 8 Loss: 1.7699
# Epoch 66 Batch 9 Loss: 2.0435
#
# *** Epoch 66 Loss 2.3491 ***
#
# check point saved!
# Best epoch so far:  66  smallest loss: 2.3490660190582275
# Time taken for the epoch 19.266 sec
#
# ========================================
# Epoch 67 Batch 2 Loss: 2.9116
# Epoch 67 Batch 3 Loss: 2.1410
# Epoch 67 Batch 4 Loss: 2.9234
# Epoch 67 Batch 5 Loss: 2.5674
# Epoch 67 Batch 6 Loss: 2.9563
# Epoch 67 Batch 7 Loss: 1.9893
# Epoch 67 Batch 8 Loss: 2.3687
# Epoch 67 Batch 9 Loss: 1.5631
# Epoch 67 Batch 10 Loss: 2.1872
#
# *** Epoch 67 Loss 2.7010 ***
#
# Best epoch so far:  66  smallest loss: 2.3490660190582275
# Time taken for the epoch 20.601 sec
#
# ========================================
# Epoch 68 Batch 2 Loss: 3.1236
# Epoch 68 Batch 3 Loss: 2.0899
# Epoch 68 Batch 4 Loss: 2.8941
# Epoch 68 Batch 5 Loss: 2.4844
# Epoch 68 Batch 6 Loss: 2.8645
# Epoch 68 Batch 7 Loss: 1.9519
# Epoch 68 Batch 8 Loss: 2.4497
# Epoch 68 Batch 9 Loss: 1.5308
# Epoch 68 Batch 10 Loss: 2.2780
#
# *** Epoch 68 Loss 2.7084 ***
#
# Best epoch so far:  66  smallest loss: 2.3490660190582275
# Time taken for the epoch 21.351 sec
#
# ========================================
# Epoch 69 Batch 2 Loss: 2.8064
# Epoch 69 Batch 3 Loss: 2.2254
# Epoch 69 Batch 4 Loss: 3.0073
# Epoch 69 Batch 5 Loss: 2.3910
# Epoch 69 Batch 6 Loss: 2.8282
# Epoch 69 Batch 7 Loss: 1.9702
# Epoch 69 Batch 8 Loss: 2.3919
# Epoch 69 Batch 9 Loss: 1.5735
# Epoch 69 Batch 10 Loss: 2.1671
#
# *** Epoch 69 Loss 2.6701 ***
# Best epoch so far:  66  smallest loss: 2.3490660190582275
# Time taken for the epoch 21.673 sec
#
# ========================================
# Epoch 70 Batch 2 Loss: 2.7820
# Epoch 70 Batch 3 Loss: 2.2148
# Epoch 70 Batch 4 Loss: 2.9852
# Epoch 70 Batch 5 Loss: 2.5880
# Epoch 70 Batch 6 Loss: 2.5667
# Epoch 70 Batch 7 Loss: 1.9679
# Epoch 70 Batch 8 Loss: 2.3935
# Epoch 70 Batch 9 Loss: 1.6496
# Epoch 70 Batch 10 Loss: 2.2987
#
# *** Epoch 70 Loss 2.6808 ***
#
# Best epoch so far:  66  smallest loss: 2.3490660190582275
# Time taken for the epoch 20.795 sec
#
# ========================================
# Epoch 71 Batch 2 Loss: 2.6369
# Epoch 71 Batch 3 Loss: 2.2470
# Epoch 71 Batch 4 Loss: 2.8122
# Epoch 71 Batch 5 Loss: 2.7990
# Epoch 71 Batch 6 Loss: 2.3271
# Epoch 71 Batch 7 Loss: 2.2285
# Epoch 71 Batch 8 Loss: 2.1879
# Epoch 71 Batch 9 Loss: 1.6736
# Epoch 71 Batch 10 Loss: 2.5152
#
# *** Epoch 71 Loss 2.6784 ***
#
# Best epoch so far:  66  smallest loss: 2.3490660190582275
# Time taken for the epoch 21.281 sec
#
# ========================================
# Epoch 72 Batch 2 Loss: 2.4357
# Epoch 72 Batch 3 Loss: 2.2586
# Epoch 72 Batch 4 Loss: 2.7744
# Epoch 72 Batch 5 Loss: 2.7760
# Epoch 72 Batch 6 Loss: 2.1549
# Epoch 72 Batch 7 Loss: 2.3865
# Epoch 72 Batch 8 Loss: 2.0703
# Epoch 72 Batch 9 Loss: 1.8371
# Epoch 72 Batch 10 Loss: 2.5432
#
# *** Epoch 72 Loss 2.6546 ***
# Best epoch so far:  66  smallest loss: 2.3490660190582275
# Time taken for the epoch 21.202 sec
#
# ========================================
# Epoch 73 Batch 2 Loss: 2.1295
# Epoch 73 Batch 3 Loss: 2.5665
# Epoch 73 Batch 4 Loss: 2.7513
# Epoch 73 Batch 5 Loss: 2.5664
# Epoch 73 Batch 6 Loss: 2.1582
# Epoch 73 Batch 7 Loss: 2.3543
# Epoch 73 Batch 8 Loss: 1.9031
# Epoch 73 Batch 9 Loss: 1.8614
# Epoch 73 Batch 10 Loss: 2.7521
#
# *** Epoch 73 Loss 2.6303 ***
#
# Best epoch so far:  66  smallest loss: 2.3490660190582275
# Time taken for the epoch 19.924 sec
#
# ========================================
# Epoch 74 Batch 2 Loss: 1.9375
# Epoch 74 Batch 3 Loss: 2.7962
# Epoch 74 Batch 4 Loss: 2.5372
# Epoch 74 Batch 5 Loss: 2.7827
# Epoch 74 Batch 6 Loss: 1.9703
# Epoch 74 Batch 7 Loss: 2.3451
# Epoch 74 Batch 8 Loss: 1.7025
# Epoch 74 Batch 9 Loss: 1.9652
#
# *** Epoch 74 Loss 2.2546 ***
#
# check point saved!
# Best epoch so far:  74  smallest loss: 2.2545900344848633
# Time taken for the epoch 18.633 sec
#
# ========================================
# Epoch 75 Batch 2 Loss: 2.7915
# Epoch 75 Batch 3 Loss: 2.0612
# Epoch 75 Batch 4 Loss: 2.8063
# Epoch 75 Batch 5 Loss: 2.4523
# Epoch 75 Batch 6 Loss: 2.8166
# Epoch 75 Batch 7 Loss: 1.9139
# Epoch 75 Batch 8 Loss: 2.2840
# Epoch 75 Batch 9 Loss: 1.5069
# Epoch 75 Batch 10 Loss: 2.1011
#
# *** Epoch 75 Loss 2.5917 ***
# Best epoch so far:  74  smallest loss: 2.2545900344848633
# Time taken for the epoch 20.199 sec
#
# ========================================
# Epoch 76 Batch 2 Loss: 2.9886
# Epoch 76 Batch 3 Loss: 2.0190
# Epoch 76 Batch 4 Loss: 2.7642
# Epoch 76 Batch 5 Loss: 2.3909
# Epoch 76 Batch 6 Loss: 2.7290
# Epoch 76 Batch 7 Loss: 1.8746
# Epoch 76 Batch 8 Loss: 2.3640
# Epoch 76 Batch 9 Loss: 1.4834
# Epoch 76 Batch 10 Loss: 2.1916
#
# *** Epoch 76 Loss 2.6006 ***
#
# Best epoch so far:  74  smallest loss: 2.2545900344848633
# Time taken for the epoch 20.166 sec
#
# ========================================
# Epoch 77 Batch 2 Loss: 2.6831
# Epoch 77 Batch 3 Loss: 2.1509
# Epoch 77 Batch 4 Loss: 2.8675
# Epoch 77 Batch 5 Loss: 2.3140
# Epoch 77 Batch 6 Loss: 2.7004
# Epoch 77 Batch 7 Loss: 1.8930
# Epoch 77 Batch 8 Loss: 2.3011
# Epoch 77 Batch 9 Loss: 1.5234
# Epoch 77 Batch 10 Loss: 2.0939
#
# *** Epoch 77 Loss 2.5659 ***
#
# Best epoch so far:  74  smallest loss: 2.2545900344848633
# Time taken for the epoch 19.918 sec
#
# ========================================
# Epoch 78 Batch 2 Loss: 2.6702
# Epoch 78 Batch 3 Loss: 2.1458
# Epoch 78 Batch 4 Loss: 2.8315
# Epoch 78 Batch 5 Loss: 2.5050
# Epoch 78 Batch 6 Loss: 2.4469
# Epoch 78 Batch 7 Loss: 1.9102
# Epoch 78 Batch 8 Loss: 2.3059
# Epoch 78 Batch 9 Loss: 1.5868
# Epoch 78 Batch 10 Loss: 2.2063
#
# *** Epoch 78 Loss 2.5761 ***
# Best epoch so far:  74  smallest loss: 2.2545900344848633
# Time taken for the epoch 19.826 sec
#
# ========================================
# Epoch 79 Batch 2 Loss: 2.5343
# Epoch 79 Batch 3 Loss: 2.1879
# Epoch 79 Batch 4 Loss: 2.6728
# Epoch 79 Batch 5 Loss: 2.7147
# Epoch 79 Batch 6 Loss: 2.2096
# Epoch 79 Batch 7 Loss: 2.1690
# Epoch 79 Batch 8 Loss: 2.1125
# Epoch 79 Batch 9 Loss: 1.6194
# Epoch 79 Batch 10 Loss: 2.4335
#
# *** Epoch 79 Loss 2.5817 ***
#
# Best epoch so far:  74  smallest loss: 2.2545900344848633
# Time taken for the epoch 19.704 sec
#
# ========================================
# Epoch 80 Batch 2 Loss: 2.3458
# Epoch 80 Batch 3 Loss: 2.1810
# Epoch 80 Batch 4 Loss: 2.6371
# Epoch 80 Batch 5 Loss: 2.6929
# Epoch 80 Batch 6 Loss: 2.0569
# Epoch 80 Batch 7 Loss: 2.3133
# Epoch 80 Batch 8 Loss: 1.9964
# Epoch 80 Batch 9 Loss: 1.7686
# Epoch 80 Batch 10 Loss: 2.4445
#
# *** Epoch 80 Loss 2.5546 ***
#
# Best epoch so far:  74  smallest loss: 2.2545900344848633
# Time taken for the epoch 19.636 sec
#
# ========================================
# Epoch 81 Batch 2 Loss: 2.0546
# Epoch 81 Batch 3 Loss: 2.4898
# Epoch 81 Batch 4 Loss: 2.6334
# Epoch 81 Batch 5 Loss: 2.4747
# Epoch 81 Batch 6 Loss: 2.0537
# Epoch 81 Batch 7 Loss: 2.2788
# Epoch 81 Batch 8 Loss: 1.8443
# Epoch 81 Batch 9 Loss: 1.8080
# Epoch 81 Batch 10 Loss: 2.6461
#
# *** Epoch 81 Loss 2.5354 ***
# Best epoch so far:  74  smallest loss: 2.2545900344848633
# Time taken for the epoch 18.876 sec
#
# ========================================
# Epoch 82 Batch 2 Loss: 1.8661
# Epoch 82 Batch 3 Loss: 2.7025
# Epoch 82 Batch 4 Loss: 2.4271
# Epoch 82 Batch 5 Loss: 2.6825
# Epoch 82 Batch 6 Loss: 1.8860
# Epoch 82 Batch 7 Loss: 2.2773
# Epoch 82 Batch 8 Loss: 1.6533
# Epoch 82 Batch 9 Loss: 1.9012
#
# *** Epoch 82 Loss 2.1745 ***
#
# check point saved!
# Best epoch so far:  82  smallest loss: 2.1745011806488037
# Time taken for the epoch 17.123 sec
#
# ========================================
# Epoch 83 Batch 2 Loss: 2.6847
# Epoch 83 Batch 3 Loss: 1.9900
# Epoch 83 Batch 4 Loss: 2.7139
# Epoch 83 Batch 5 Loss: 2.3739
# Epoch 83 Batch 6 Loss: 2.7244
# Epoch 83 Batch 7 Loss: 1.8507
# Epoch 83 Batch 8 Loss: 2.2227
# Epoch 83 Batch 9 Loss: 1.4688
# Epoch 83 Batch 10 Loss: 2.0529
#
# *** Epoch 83 Loss 2.5103 ***
#
# Best epoch so far:  82  smallest loss: 2.1745011806488037
# Time taken for the epoch 19.369 sec
#
# ========================================
# Epoch 84 Batch 2 Loss: 2.9009
# Epoch 84 Batch 3 Loss: 1.9765
# Epoch 84 Batch 4 Loss: 2.6800
# Epoch 84 Batch 5 Loss: 2.3286
# Epoch 84 Batch 6 Loss: 2.6587
# Epoch 84 Batch 7 Loss: 1.8545
# Epoch 84 Batch 8 Loss: 2.3337
# Epoch 84 Batch 9 Loss: 1.4807
# Epoch 84 Batch 10 Loss: 2.1802
#
# *** Epoch 84 Loss 2.5492 ***
# Best epoch so far:  82  smallest loss: 2.1745011806488037
# Time taken for the epoch 21.248 sec
#
# ========================================
# Epoch 85 Batch 2 Loss: 2.5919
# Epoch 85 Batch 3 Loss: 2.1042
# Epoch 85 Batch 4 Loss: 2.8436
# Epoch 85 Batch 5 Loss: 2.2955
# Epoch 85 Batch 6 Loss: 2.7089
# Epoch 85 Batch 7 Loss: 1.8351
# Epoch 85 Batch 8 Loss: 2.2462
# Epoch 85 Batch 9 Loss: 1.5080
# Epoch 85 Batch 10 Loss: 2.1249
#
# *** Epoch 85 Loss 2.5323 ***
#
# Best epoch so far:  82  smallest loss: 2.1745011806488037
# Time taken for the epoch 16.802 sec
#
# ========================================
# Epoch 86 Batch 2 Loss: 2.6540
# Epoch 86 Batch 3 Loss: 2.1644
# Epoch 86 Batch 4 Loss: 2.7330
# Epoch 86 Batch 5 Loss: 2.4298
# Epoch 86 Batch 6 Loss: 2.3868
# Epoch 86 Batch 7 Loss: 1.8597
# Epoch 86 Batch 8 Loss: 2.2631
# Epoch 86 Batch 9 Loss: 1.5475
# Epoch 86 Batch 10 Loss: 2.1518
#
# *** Epoch 86 Loss 2.5238 ***
#
# Best epoch so far:  82  smallest loss: 2.1745011806488037
# Time taken for the epoch 18.772 sec
#
# ========================================
# Epoch 87 Batch 2 Loss: 2.4685
# Epoch 87 Batch 3 Loss: 2.1136
# Epoch 87 Batch 4 Loss: 2.5764
# Epoch 87 Batch 5 Loss: 2.6278
# Epoch 87 Batch 6 Loss: 2.1234
# Epoch 87 Batch 7 Loss: 2.0840
# Epoch 87 Batch 8 Loss: 2.0507
# Epoch 87 Batch 9 Loss: 1.5782
# Epoch 87 Batch 10 Loss: 2.3595
#
# *** Epoch 87 Loss 2.4978 ***
# Best epoch so far:  82  smallest loss: 2.1745011806488037
# Time taken for the epoch 19.317 sec
#
# ========================================
# Epoch 88 Batch 2 Loss: 2.2562
# Epoch 88 Batch 3 Loss: 2.1161
# Epoch 88 Batch 4 Loss: 2.5173
# Epoch 88 Batch 5 Loss: 2.5874
# Epoch 88 Batch 6 Loss: 1.9752
# Epoch 88 Batch 7 Loss: 2.2204
# Epoch 88 Batch 8 Loss: 1.9253
# Epoch 88 Batch 9 Loss: 1.7094
# Epoch 88 Batch 10 Loss: 2.3580
#
# *** Epoch 88 Loss 2.4582 ***
#
# Best epoch so far:  82  smallest loss: 2.1745011806488037
# Time taken for the epoch 18.325 sec
#
# ========================================
# Epoch 89 Batch 2 Loss: 1.9703
# Epoch 89 Batch 3 Loss: 2.3813
# Epoch 89 Batch 4 Loss: 2.5015
# Epoch 89 Batch 5 Loss: 2.3760
# Epoch 89 Batch 6 Loss: 1.9678
# Epoch 89 Batch 7 Loss: 2.1829
# Epoch 89 Batch 8 Loss: 1.7712
# Epoch 89 Batch 9 Loss: 1.7303
# Epoch 89 Batch 10 Loss: 2.5329
#
# *** Epoch 89 Loss 2.4268 ***
#
# Best epoch so far:  82  smallest loss: 2.1745011806488037
# Time taken for the epoch 17.266 sec
#
# ========================================
# Epoch 90 Batch 2 Loss: 1.7977
# Epoch 90 Batch 3 Loss: 2.5919
# Epoch 90 Batch 4 Loss: 2.2990
# Epoch 90 Batch 5 Loss: 2.5636
# Epoch 90 Batch 6 Loss: 1.7966
# Epoch 90 Batch 7 Loss: 2.1701
# Epoch 90 Batch 8 Loss: 1.5818
# Epoch 90 Batch 9 Loss: 1.8238
#
# *** Epoch 90 Loss 2.0781 ***
#
# check point saved!
# Best epoch so far:  90  smallest loss: 2.0780768394470215
# Time taken for the epoch 16.869 sec
#
# ========================================
# Epoch 91 Batch 2 Loss: 2.5711
# Epoch 91 Batch 3 Loss: 1.9013
# Epoch 91 Batch 4 Loss: 2.5739
# Epoch 91 Batch 5 Loss: 2.2384
# Epoch 91 Batch 6 Loss: 2.5814
# Epoch 91 Batch 7 Loss: 1.7571
# Epoch 91 Batch 8 Loss: 2.1071
# Epoch 91 Batch 9 Loss: 1.3952
# Epoch 91 Batch 10 Loss: 1.9484
#
# *** Epoch 91 Loss 2.3842 ***
#
# Best epoch so far:  90  smallest loss: 2.0780768394470215
# Time taken for the epoch 17.329 sec
#
# ========================================
# Epoch 92 Batch 2 Loss: 2.7407
# Epoch 92 Batch 3 Loss: 1.8715
# Epoch 92 Batch 4 Loss: 2.5058
# Epoch 92 Batch 5 Loss: 2.1969
# Epoch 92 Batch 6 Loss: 2.4980
# Epoch 92 Batch 7 Loss: 1.7222
# Epoch 92 Batch 8 Loss: 2.1722
# Epoch 92 Batch 9 Loss: 1.3689
# Epoch 92 Batch 10 Loss: 2.0228
#
# *** Epoch 92 Loss 2.3874 ***
#
# Best epoch so far:  90  smallest loss: 2.0780768394470215
# Time taken for the epoch 18.596 sec
#
# ========================================
# Epoch 93 Batch 2 Loss: 2.4518
# Epoch 93 Batch 3 Loss: 1.9952
# Epoch 93 Batch 4 Loss: 2.5770
# Epoch 93 Batch 5 Loss: 2.1362
# Epoch 93 Batch 6 Loss: 2.4627
# Epoch 93 Batch 7 Loss: 1.7339
# Epoch 93 Batch 8 Loss: 2.1129
# Epoch 93 Batch 9 Loss: 1.3998
# Epoch 93 Batch 10 Loss: 1.9261
#
# *** Epoch 93 Loss 2.3494 ***
# Best epoch so far:  90  smallest loss: 2.0780768394470215
# Time taken for the epoch 18.573 sec
#
# ========================================
# Epoch 94 Batch 2 Loss: 2.4291
# Epoch 94 Batch 3 Loss: 1.9856
# Epoch 94 Batch 4 Loss: 2.5556
# Epoch 94 Batch 5 Loss: 2.3116
# Epoch 94 Batch 6 Loss: 2.2065
# Epoch 94 Batch 7 Loss: 1.7508
# Epoch 94 Batch 8 Loss: 2.1091
# Epoch 94 Batch 9 Loss: 1.4651
# Epoch 94 Batch 10 Loss: 2.0338
#
# *** Epoch 94 Loss 2.3559 ***
#
# Best epoch so far:  90  smallest loss: 2.0780768394470215
# Time taken for the epoch 18.409 sec
#
# ========================================
# Epoch 95 Batch 2 Loss: 2.3043
# Epoch 95 Batch 3 Loss: 2.0139
# Epoch 95 Batch 4 Loss: 2.4032
# Epoch 95 Batch 5 Loss: 2.4932
# Epoch 95 Batch 6 Loss: 1.9932
# Epoch 95 Batch 7 Loss: 1.9810
# Epoch 95 Batch 8 Loss: 1.9312
# Epoch 95 Batch 9 Loss: 1.4859
# Epoch 95 Batch 10 Loss: 2.2276
#
# *** Epoch 95 Loss 2.3542 ***
#
# Best epoch so far:  90  smallest loss: 2.0780768394470215
# Time taken for the epoch 17.370 sec
#
# ========================================
# Epoch 96 Batch 2 Loss: 2.1299
# Epoch 96 Batch 3 Loss: 2.0039
# Epoch 96 Batch 4 Loss: 2.3794
# Epoch 96 Batch 5 Loss: 2.4700
# Epoch 96 Batch 6 Loss: 1.8518
# Epoch 96 Batch 7 Loss: 2.1087
# Epoch 96 Batch 8 Loss: 1.8351
# Epoch 96 Batch 9 Loss: 1.6322
# Epoch 96 Batch 10 Loss: 2.2424
#
# *** Epoch 96 Loss 2.3317 ***
# Best epoch so far:  90  smallest loss: 2.0780768394470215
# Time taken for the epoch 17.654 sec
#
# ========================================
# Epoch 97 Batch 2 Loss: 1.8671
# Epoch 97 Batch 3 Loss: 2.2591
# Epoch 97 Batch 4 Loss: 2.3723
# Epoch 97 Batch 5 Loss: 2.2718
# Epoch 97 Batch 6 Loss: 1.8588
# Epoch 97 Batch 7 Loss: 2.0758
# Epoch 97 Batch 8 Loss: 1.6854
# Epoch 97 Batch 9 Loss: 1.6536
# Epoch 97 Batch 10 Loss: 2.4093
#
# *** Epoch 97 Loss 2.3066 ***
#
# Best epoch so far:  90  smallest loss: 2.0780768394470215
# Time taken for the epoch 16.318 sec
#
# ========================================
# Epoch 98 Batch 2 Loss: 1.7070
# Epoch 98 Batch 3 Loss: 2.4624
# Epoch 98 Batch 4 Loss: 2.1773
# Epoch 98 Batch 5 Loss: 2.4522
# Epoch 98 Batch 6 Loss: 1.7020
# Epoch 98 Batch 7 Loss: 2.0667
# Epoch 98 Batch 8 Loss: 1.5087
# Epoch 98 Batch 9 Loss: 1.7385
#
# *** Epoch 98 Loss 1.9768 ***
#
# check point saved!
# Best epoch so far:  98  smallest loss: 1.9768424034118652
# Time taken for the epoch 16.935 sec
#
# ========================================
# Epoch 99 Batch 2 Loss: 2.4504
# Epoch 99 Batch 3 Loss: 1.8111
# Epoch 99 Batch 4 Loss: 2.4443
# Epoch 99 Batch 5 Loss: 2.1244
# Epoch 99 Batch 6 Loss: 2.4583
# Epoch 99 Batch 7 Loss: 1.6684
# Epoch 99 Batch 8 Loss: 2.0101
# Epoch 99 Batch 9 Loss: 1.3326
# Epoch 99 Batch 10 Loss: 1.8573
#
# *** Epoch 99 Loss 2.2696 ***
# Best epoch so far:  98  smallest loss: 1.9768424034118652
# Time taken for the epoch 18.849 sec
#
# ========================================
# Epoch 100 Batch 2 Loss: 2.6036
# Epoch 100 Batch 3 Loss: 1.7917
# Epoch 100 Batch 4 Loss: 2.3824
# Epoch 100 Batch 5 Loss: 2.0908
# Epoch 100 Batch 6 Loss: 2.3756
# Epoch 100 Batch 7 Loss: 1.6393
# Epoch 100 Batch 8 Loss: 2.0824
# Epoch 100 Batch 9 Loss: 1.3156
# Epoch 100 Batch 10 Loss: 1.9303
#
# *** Epoch 100 Loss 2.2764 ***
#
# Best epoch so far:  98  smallest loss: 1.9768424034118652
# Time taken for the epoch 18.408 sec
#
# ========================================
# Epoch 101 Batch 2 Loss: 2.3281
# Epoch 101 Batch 3 Loss: 1.9225
# Epoch 101 Batch 4 Loss: 2.4540
# Epoch 101 Batch 5 Loss: 2.0591
# Epoch 101 Batch 6 Loss: 2.3478
# Epoch 101 Batch 7 Loss: 1.6520
# Epoch 101 Batch 8 Loss: 2.0437
# Epoch 101 Batch 9 Loss: 1.3649
# Epoch 101 Batch 10 Loss: 1.8752
#
# *** Epoch 101 Loss 2.2559 ***
#
# Best epoch so far:  98  smallest loss: 1.9768424034118652
# Time taken for the epoch 22.867 sec
#
# ========================================
# Epoch 102 Batch 2 Loss: 2.3225
# Epoch 102 Batch 3 Loss: 1.9066
# Epoch 102 Batch 4 Loss: 2.4348
# Epoch 102 Batch 5 Loss: 2.2564
# Epoch 102 Batch 6 Loss: 2.1114
# Epoch 102 Batch 7 Loss: 1.6844
# Epoch 102 Batch 8 Loss: 2.0272
# Epoch 102 Batch 9 Loss: 1.4191
# Epoch 102 Batch 10 Loss: 1.9877
#
# *** Epoch 102 Loss 2.2688 ***
# Best epoch so far:  98  smallest loss: 1.9768424034118652
# Time taken for the epoch 18.207 sec
#
# ========================================
# Epoch 103 Batch 2 Loss: 2.2324
# Epoch 103 Batch 3 Loss: 1.9503
# Epoch 103 Batch 4 Loss: 2.3182
# Epoch 103 Batch 5 Loss: 2.4166
# Epoch 103 Batch 6 Loss: 1.8991
# Epoch 103 Batch 7 Loss: 1.9394
# Epoch 103 Batch 8 Loss: 1.8836
# Epoch 103 Batch 9 Loss: 1.4388
# Epoch 103 Batch 10 Loss: 2.1679
#
# *** Epoch 103 Loss 2.2808 ***
#
# Best epoch so far:  98  smallest loss: 1.9768424034118652
# Time taken for the epoch 18.860 sec
#
# ========================================
# Epoch 104 Batch 2 Loss: 2.0439
# Epoch 104 Batch 3 Loss: 1.9448
# Epoch 104 Batch 4 Loss: 2.2908
# Epoch 104 Batch 5 Loss: 2.4207
# Epoch 104 Batch 6 Loss: 1.7806
# Epoch 104 Batch 7 Loss: 2.0374
# Epoch 104 Batch 8 Loss: 1.7720
# Epoch 104 Batch 9 Loss: 1.5872
# Epoch 104 Batch 10 Loss: 2.1786
#
# *** Epoch 104 Loss 2.2570 ***
#
# Best epoch so far:  98  smallest loss: 1.9768424034118652
# Time taken for the epoch 18.452 sec
#
# ========================================
# Epoch 105 Batch 2 Loss: 1.8004
# Epoch 105 Batch 3 Loss: 2.1930
# Epoch 105 Batch 4 Loss: 2.2639
# Epoch 105 Batch 5 Loss: 2.1970
# Epoch 105 Batch 6 Loss: 1.7728
# Epoch 105 Batch 7 Loss: 2.0005
# Epoch 105 Batch 8 Loss: 1.6344
# Epoch 105 Batch 9 Loss: 1.6081
# Epoch 105 Batch 10 Loss: 2.3073
#
# *** Epoch 105 Loss 2.2222 ***
# Best epoch so far:  98  smallest loss: 1.9768424034118652
# Time taken for the epoch 17.603 sec
#
# ========================================
# Epoch 106 Batch 2 Loss: 1.6326
# Epoch 106 Batch 3 Loss: 2.3646
# Epoch 106 Batch 4 Loss: 2.0722
# Epoch 106 Batch 5 Loss: 2.3495
# Epoch 106 Batch 6 Loss: 1.6194
# Epoch 106 Batch 7 Loss: 1.9839
# Epoch 106 Batch 8 Loss: 1.4553
# Epoch 106 Batch 9 Loss: 1.6722
#
# *** Epoch 106 Loss 1.8937 ***
#
# check point saved!
# Best epoch so far:  106  smallest loss: 1.8937244415283203
# Time taken for the epoch 16.535 sec
#
# ========================================
# Epoch 107 Batch 2 Loss: 2.3384
# Epoch 107 Batch 3 Loss: 1.7168
# Epoch 107 Batch 4 Loss: 2.3313
# Epoch 107 Batch 5 Loss: 2.0320
# Epoch 107 Batch 6 Loss: 2.3448
# Epoch 107 Batch 7 Loss: 1.5807
# Epoch 107 Batch 8 Loss: 1.9223
# Epoch 107 Batch 9 Loss: 1.2847
# Epoch 107 Batch 10 Loss: 1.7813
#
# *** Epoch 107 Loss 2.1665 ***
#
# Best epoch so far:  106  smallest loss: 1.8937244415283203
# Time taken for the epoch 17.413 sec
#
# ========================================
# Epoch 108 Batch 2 Loss: 2.4821
# Epoch 108 Batch 3 Loss: 1.7059
# Epoch 108 Batch 4 Loss: 2.2535
# Epoch 108 Batch 5 Loss: 2.0107
# Epoch 108 Batch 6 Loss: 2.2696
# Epoch 108 Batch 7 Loss: 1.5605
# Epoch 108 Batch 8 Loss: 1.9798
# Epoch 108 Batch 9 Loss: 1.2579
# Epoch 108 Batch 10 Loss: 1.8437
#
# *** Epoch 108 Loss 2.1705 ***
# Best epoch so far:  106  smallest loss: 1.8937244415283203
# Time taken for the epoch 18.787 sec
#
# ========================================
# Epoch 109 Batch 2 Loss: 2.2124
# Epoch 109 Batch 3 Loss: 1.8311
# Epoch 109 Batch 4 Loss: 2.3107
# Epoch 109 Batch 5 Loss: 1.9598
# Epoch 109 Batch 6 Loss: 2.2267
# Epoch 109 Batch 7 Loss: 1.5717
# Epoch 109 Batch 8 Loss: 1.9326
# Epoch 109 Batch 9 Loss: 1.2822
# Epoch 109 Batch 10 Loss: 1.7633
#
# *** Epoch 109 Loss 2.1363 ***
#
# Best epoch so far:  106  smallest loss: 1.8937244415283203
# Time taken for the epoch 19.060 sec
#
# ========================================
# Epoch 110 Batch 2 Loss: 2.1849
# Epoch 110 Batch 3 Loss: 1.8174
# Epoch 110 Batch 4 Loss: 2.2860
# Epoch 110 Batch 5 Loss: 2.1406
# Epoch 110 Batch 6 Loss: 2.0013
# Epoch 110 Batch 7 Loss: 1.6004
# Epoch 110 Batch 8 Loss: 1.9279
# Epoch 110 Batch 9 Loss: 1.3397
# Epoch 110 Batch 10 Loss: 1.8591
#
# *** Epoch 110 Loss 2.1447 ***
#
# Best epoch so far:  106  smallest loss: 1.8937244415283203
# Time taken for the epoch 18.788 sec
#
# ========================================
# Epoch 111 Batch 2 Loss: 2.0844
# Epoch 111 Batch 3 Loss: 1.8596
# Epoch 111 Batch 4 Loss: 2.1529
# Epoch 111 Batch 5 Loss: 2.3020
# Epoch 111 Batch 6 Loss: 1.7837
# Epoch 111 Batch 7 Loss: 1.8183
# Epoch 111 Batch 8 Loss: 1.7722
# Epoch 111 Batch 9 Loss: 1.3595
# Epoch 111 Batch 10 Loss: 2.0548
#
# *** Epoch 111 Loss 2.1484 ***
# Best epoch so far:  106  smallest loss: 1.8937244415283203
# Time taken for the epoch 19.159 sec
#
# ========================================
# Epoch 112 Batch 2 Loss: 1.9201
# Epoch 112 Batch 3 Loss: 1.8361
# Epoch 112 Batch 4 Loss: 2.1421
# Epoch 112 Batch 5 Loss: 2.2997
# Epoch 112 Batch 6 Loss: 1.6599
# Epoch 112 Batch 7 Loss: 1.9202
# Epoch 112 Batch 8 Loss: 1.6830
# Epoch 112 Batch 9 Loss: 1.5063
# Epoch 112 Batch 10 Loss: 2.0817
#
# *** Epoch 112 Loss 2.1311 ***
#
# Best epoch so far:  106  smallest loss: 1.8937244415283203
# Time taken for the epoch 18.014 sec
#
# ========================================
# Epoch 113 Batch 2 Loss: 1.7048
# Epoch 113 Batch 3 Loss: 2.0828
# Epoch 113 Batch 4 Loss: 2.1329
# Epoch 113 Batch 5 Loss: 2.0957
# Epoch 113 Batch 6 Loss: 1.7095
# Epoch 113 Batch 7 Loss: 1.9724
# Epoch 113 Batch 8 Loss: 1.5748
# Epoch 113 Batch 9 Loss: 1.5244
# Epoch 113 Batch 10 Loss: 2.1868
#
# *** Epoch 113 Loss 2.1230 ***
#
# Best epoch so far:  106  smallest loss: 1.8937244415283203
# Time taken for the epoch 18.406 sec
#
# ========================================
# Epoch 114 Batch 2 Loss: 1.5478
# Epoch 114 Batch 3 Loss: 2.3238
# Epoch 114 Batch 4 Loss: 2.0294
# Epoch 114 Batch 5 Loss: 2.2931
# Epoch 114 Batch 6 Loss: 1.5253
# Epoch 114 Batch 7 Loss: 1.9180
# Epoch 114 Batch 8 Loss: 1.4374
# Epoch 114 Batch 9 Loss: 1.6726
#
# *** Epoch 114 Loss 1.8434 ***
#
# check point saved!
# Best epoch so far:  114  smallest loss: 1.8434101343154907
# Time taken for the epoch 16.002 sec
#
# ========================================
# Epoch 115 Batch 2 Loss: 2.3089
# Epoch 115 Batch 3 Loss: 1.6565
# Epoch 115 Batch 4 Loss: 2.2215
# Epoch 115 Batch 5 Loss: 1.9561
# Epoch 115 Batch 6 Loss: 2.3284
# Epoch 115 Batch 7 Loss: 1.5242
# Epoch 115 Batch 8 Loss: 1.8462
# Epoch 115 Batch 9 Loss: 1.2372
# Epoch 115 Batch 10 Loss: 1.7243
#
# *** Epoch 115 Loss 2.1004 ***
#
# Best epoch so far:  114  smallest loss: 1.8434101343154907
# Time taken for the epoch 17.402 sec
#
# ========================================
# Epoch 116 Batch 2 Loss: 2.3759
# Epoch 116 Batch 3 Loss: 1.6503
# Epoch 116 Batch 4 Loss: 2.1550
# Epoch 116 Batch 5 Loss: 1.9142
# Epoch 116 Batch 6 Loss: 2.1699
# Epoch 116 Batch 7 Loss: 1.4862
# Epoch 116 Batch 8 Loss: 1.8989
# Epoch 116 Batch 9 Loss: 1.2069
# Epoch 116 Batch 10 Loss: 1.7735
#
# *** Epoch 116 Loss 2.0789 ***
#
# Best epoch so far:  114  smallest loss: 1.8434101343154907
# Time taken for the epoch 19.017 sec
#
# ========================================
# Epoch 117 Batch 2 Loss: 2.1087
# Epoch 117 Batch 3 Loss: 1.7411
# Epoch 117 Batch 4 Loss: 2.1914
# Epoch 117 Batch 5 Loss: 1.8744
# Epoch 117 Batch 6 Loss: 2.1244
# Epoch 117 Batch 7 Loss: 1.4831
# Epoch 117 Batch 8 Loss: 1.8423
# Epoch 117 Batch 9 Loss: 1.2206
# Epoch 117 Batch 10 Loss: 1.6783
#
# *** Epoch 117 Loss 2.0330 ***
# Best epoch so far:  114  smallest loss: 1.8434101343154907
# Time taken for the epoch 18.808 sec
#
# ========================================
# Epoch 118 Batch 2 Loss: 2.0788
# Epoch 118 Batch 3 Loss: 1.7206
# Epoch 118 Batch 4 Loss: 2.1537
# Epoch 118 Batch 5 Loss: 2.0317
# Epoch 118 Batch 6 Loss: 1.8797
# Epoch 118 Batch 7 Loss: 1.5103
# Epoch 118 Batch 8 Loss: 1.8167
# Epoch 118 Batch 9 Loss: 1.2734
# Epoch 118 Batch 10 Loss: 1.7612
#
# *** Epoch 118 Loss 2.0282 ***
#
# Best epoch so far:  114  smallest loss: 1.8434101343154907
# Time taken for the epoch 18.227 sec
#
# ========================================
# Epoch 119 Batch 2 Loss: 1.9587
# Epoch 119 Batch 3 Loss: 1.7502
# Epoch 119 Batch 4 Loss: 2.0136
# Epoch 119 Batch 5 Loss: 2.1750
# Epoch 119 Batch 6 Loss: 1.6703
# Epoch 119 Batch 7 Loss: 1.7115
# Epoch 119 Batch 8 Loss: 1.6601
# Epoch 119 Batch 9 Loss: 1.2880
# Epoch 119 Batch 10 Loss: 1.9135
#
# ...
# Epoch 121 Batch 5 Loss: 1.9634
# Epoch 121 Batch 6 Loss: 1.5579
# Epoch 121 Batch 7 Loss: 1.7737
# Epoch 121 Batch 8 Loss: 1.4574
# Epoch 121 Batch 9 Loss: 1.4247
# Epoch 121 Batch 10 Loss: 2.0477
#
# *** Epoch 121 Loss 1.9649 ***
#
# Best epoch so far:  114  smallest loss: 1.8434101343154907
# Time taken for the epoch 17.826 sec
#
# ========================================
# Epoch 122 Batch 2 Loss: 1.4384
# Epoch 122 Batch 3 Loss: 2.1062
# Epoch 122 Batch 4 Loss: 1.8416
# Epoch 122 Batch 5 Loss: 2.1077
# Epoch 122 Batch 6 Loss: 1.4257
# Epoch 122 Batch 7 Loss: 1.7685
# Epoch 122 Batch 8 Loss: 1.3127
# Epoch 122 Batch 9 Loss: 1.4903
#
# *** Epoch 122 Loss 1.6864 ***
#
# check point saved!
# Best epoch so far:  122  smallest loss: 1.6863760948181152
# Time taken for the epoch 17.011 sec
#
# ========================================
# Epoch 123 Batch 2 Loss: 2.0870
# Epoch 123 Batch 3 Loss: 1.5283
# Epoch 123 Batch 4 Loss: 2.0658
# Epoch 123 Batch 5 Loss: 1.8153
# Epoch 123 Batch 6 Loss: 2.0981
# Epoch 123 Batch 7 Loss: 1.3922
# Epoch 123 Batch 8 Loss: 1.7200
# Epoch 123 Batch 9 Loss: 1.1550
# Epoch 123 Batch 10 Loss: 1.5945
#
# *** Epoch 123 Loss 1.9320 ***
# Best epoch so far:  122  smallest loss: 1.6863760948181152
# Time taken for the epoch 18.208 sec
#
# ========================================
# Epoch 124 Batch 2 Loss: 2.1948
# Epoch 124 Batch 3 Loss: 1.5124
# Epoch 124 Batch 4 Loss: 1.9960
# Epoch 124 Batch 5 Loss: 1.7954
# Epoch 124 Batch 6 Loss: 2.0361
# Epoch 124 Batch 7 Loss: 1.3670
# Epoch 124 Batch 8 Loss: 1.7639
# Epoch 124 Batch 9 Loss: 1.1349
# Epoch 124 Batch 10 Loss: 1.6488
#
# *** Epoch 124 Loss 1.9311 ***
#
# Best epoch so far:  122  smallest loss: 1.6863760948181152
# Time taken for the epoch 18.681 sec
#
# ========================================
# Epoch 125 Batch 2 Loss: 1.9493
# Epoch 125 Batch 3 Loss: 1.6285
# Epoch 125 Batch 4 Loss: 2.0322
# Epoch 125 Batch 5 Loss: 1.7492
# Epoch 125 Batch 6 Loss: 1.9749
# Epoch 125 Batch 7 Loss: 1.3932
# Epoch 125 Batch 8 Loss: 1.7334
# Epoch 125 Batch 9 Loss: 1.1488
# Epoch 125 Batch 10 Loss: 1.5606
#
# *** Epoch 125 Loss 1.8963 ***
#
# Best epoch so far:  122  smallest loss: 1.6863760948181152
# Time taken for the epoch 16.362 sec
#
# ========================================
# Epoch 126 Batch 2 Loss: 1.9262
# Epoch 126 Batch 3 Loss: 1.6310
# Epoch 126 Batch 4 Loss: 2.0145
# Epoch 126 Batch 5 Loss: 1.9134
# Epoch 126 Batch 6 Loss: 1.7392
# Epoch 126 Batch 7 Loss: 1.4272
# Epoch 126 Batch 8 Loss: 1.7158
# Epoch 126 Batch 9 Loss: 1.2029
# Epoch 126 Batch 10 Loss: 1.6572
#
# *** Epoch 126 Loss 1.9034 ***
# Best epoch so far:  122  smallest loss: 1.6863760948181152
# Time taken for the epoch 17.972 sec
#
# ========================================
# Epoch 127 Batch 2 Loss: 1.8315
# Epoch 127 Batch 3 Loss: 1.6488
# Epoch 127 Batch 4 Loss: 1.8931
# Epoch 127 Batch 5 Loss: 2.0760
# Epoch 127 Batch 6 Loss: 1.5648
# Epoch 127 Batch 7 Loss: 1.6458
# Epoch 127 Batch 8 Loss: 1.5924
# Epoch 127 Batch 9 Loss: 1.2379
# Epoch 127 Batch 10 Loss: 1.8204
#
# *** Epoch 127 Loss 1.9138 ***
#
# Best epoch so far:  122  smallest loss: 1.6863760948181152
# Time taken for the epoch 18.133 sec
#
# ========================================
# Epoch 128 Batch 2 Loss: 1.6939
# Epoch 128 Batch 3 Loss: 1.6589
# Epoch 128 Batch 4 Loss: 1.9195
# Epoch 128 Batch 5 Loss: 2.0978
# Epoch 128 Batch 6 Loss: 1.4594
# Epoch 128 Batch 7 Loss: 1.7223
# Epoch 128 Batch 8 Loss: 1.5573
# Epoch 128 Batch 9 Loss: 1.4166
# Epoch 128 Batch 10 Loss: 1.9148
#
# *** Epoch 128 Loss 1.9301 ***
#
# Best epoch so far:  122  smallest loss: 1.6863760948181152
# Time taken for the epoch 17.199 sec
#
# ========================================
# Epoch 129 Batch 2 Loss: 1.5307
# Epoch 129 Batch 3 Loss: 1.8354
# Epoch 129 Batch 4 Loss: 1.9044
# Epoch 129 Batch 5 Loss: 1.9472
# Epoch 129 Batch 6 Loss: 1.5687
# Epoch 129 Batch 7 Loss: 1.7682
# Epoch 129 Batch 8 Loss: 1.4079
# Epoch 129 Batch 9 Loss: 1.3626
# Epoch 129 Batch 10 Loss: 1.9712
#
# *** Epoch 129 Loss 1.9120 ***
# Best epoch so far:  122  smallest loss: 1.6863760948181152
# Time taken for the epoch 18.205 sec
#
# ========================================
# Epoch 130 Batch 2 Loss: 1.4018
# Epoch 130 Batch 3 Loss: 2.0813
# Epoch 130 Batch 4 Loss: 1.7990
# Epoch 130 Batch 5 Loss: 2.0640
# Epoch 130 Batch 6 Loss: 1.3487
# Epoch 130 Batch 7 Loss: 1.6921
# Epoch 130 Batch 8 Loss: 1.2705
# Epoch 130 Batch 9 Loss: 1.4655
#
# *** Epoch 130 Loss 1.6404 ***
#
# check point saved!
# Best epoch so far:  130  smallest loss: 1.6403682231903076
# Time taken for the epoch 15.151 sec
#
# ========================================
# Epoch 131 Batch 2 Loss: 2.0750
# Epoch 131 Batch 3 Loss: 1.4712
# Epoch 131 Batch 4 Loss: 1.9907
# Epoch 131 Batch 5 Loss: 1.7308
# Epoch 131 Batch 6 Loss: 2.0073
# Epoch 131 Batch 7 Loss: 1.3356
# Epoch 131 Batch 8 Loss: 1.6616
# Epoch 131 Batch 9 Loss: 1.1170
# Epoch 131 Batch 10 Loss: 1.5285
#
# *** Epoch 131 Loss 1.8647 ***
#
# Best epoch so far:  130  smallest loss: 1.6403682231903076
# Time taken for the epoch 18.159 sec
#
# ========================================
# Epoch 132 Batch 2 Loss: 2.0849
# Epoch 132 Batch 3 Loss: 1.4463
# Epoch 132 Batch 4 Loss: 1.9049
# Epoch 132 Batch 5 Loss: 1.7115
# Epoch 132 Batch 6 Loss: 1.9416
# Epoch 132 Batch 7 Loss: 1.3010
# Epoch 132 Batch 8 Loss: 1.6970
# Epoch 132 Batch 9 Loss: 1.0856
# Epoch 132 Batch 10 Loss: 1.5637
#
# *** Epoch 132 Loss 1.8421 ***
# Best epoch so far:  130  smallest loss: 1.6403682231903076
# Time taken for the epoch 19.043 sec
#
# ========================================
# Epoch 133 Batch 2 Loss: 1.8357
# Epoch 133 Batch 3 Loss: 1.5480
# Epoch 133 Batch 4 Loss: 1.9382
# Epoch 133 Batch 5 Loss: 1.6852
# Epoch 133 Batch 6 Loss: 1.8768
# Epoch 133 Batch 7 Loss: 1.3084
# Epoch 133 Batch 8 Loss: 1.6330
# Epoch 133 Batch 9 Loss: 1.0949
# Epoch 133 Batch 10 Loss: 1.4991
#
# *** Epoch 133 Loss 1.8024 ***
#
# Best epoch so far:  130  smallest loss: 1.6403682231903076
# Time taken for the epoch 17.130 sec
#
# ========================================
# Epoch 134 Batch 2 Loss: 1.8243
# Epoch 134 Batch 3 Loss: 1.5341
# Epoch 134 Batch 4 Loss: 1.8973
# Epoch 134 Batch 5 Loss: 1.8220
# Epoch 134 Batch 6 Loss: 1.6361
# Epoch 134 Batch 7 Loss: 1.3437
# Epoch 134 Batch 8 Loss: 1.6206
# Epoch 134 Batch 9 Loss: 1.1375
# Epoch 134 Batch 10 Loss: 1.5539
#
# *** Epoch 134 Loss 1.7962 ***
#
# Best epoch so far:  130  smallest loss: 1.6403682231903076
# Time taken for the epoch 18.631 sec
#
# ========================================
# Epoch 135 Batch 2 Loss: 1.7133
# Epoch 135 Batch 3 Loss: 1.5514
# Epoch 135 Batch 4 Loss: 1.7736
# Epoch 135 Batch 5 Loss: 1.9697
# Epoch 135 Batch 6 Loss: 1.4666
# Epoch 135 Batch 7 Loss: 1.5186
# Epoch 135 Batch 8 Loss: 1.4703
# Epoch 135 Batch 9 Loss: 1.1421
# Epoch 135 Batch 10 Loss: 1.7082
#
# *** Epoch 135 Loss 1.7892 ***
# Best epoch so far:  130  smallest loss: 1.6403682231903076
# Time taken for the epoch 16.487 sec
#
# ========================================
# Epoch 136 Batch 2 Loss: 1.5873
# Epoch 136 Batch 3 Loss: 1.5354
# Epoch 136 Batch 4 Loss: 1.7528
# Epoch 136 Batch 5 Loss: 1.9151
# Epoch 136 Batch 6 Loss: 1.3468
# Epoch 136 Batch 7 Loss: 1.6110
# Epoch 136 Batch 8 Loss: 1.4321
# Epoch 136 Batch 9 Loss: 1.2656
# Epoch 136 Batch 10 Loss: 1.7021
#
# *** Epoch 136 Loss 1.7685 ***
#
# Best epoch so far:  130  smallest loss: 1.6403682231903076
# Time taken for the epoch 18.085 sec
#
# ========================================
# Epoch 137 Batch 2 Loss: 1.3784
# Epoch 137 Batch 3 Loss: 1.7045
# Epoch 137 Batch 4 Loss: 1.7878
# Epoch 137 Batch 5 Loss: 1.7830
# Epoch 137 Batch 6 Loss: 1.3632
# Epoch 137 Batch 7 Loss: 1.5615
# Epoch 137 Batch 8 Loss: 1.3013
# Epoch 137 Batch 9 Loss: 1.2978
# Epoch 137 Batch 10 Loss: 1.8736
#
# *** Epoch 137 Loss 1.7564 ***
#
# Best epoch so far:  130  smallest loss: 1.6403682231903076
# Time taken for the epoch 17.779 sec
#
# ========================================
# Epoch 138 Batch 2 Loss: 1.2713
# Epoch 138 Batch 3 Loss: 1.8590
# Epoch 138 Batch 4 Loss: 1.6239
# Epoch 138 Batch 5 Loss: 1.9320
# Epoch 138 Batch 6 Loss: 1.2814
# Epoch 138 Batch 7 Loss: 1.6023
# Epoch 138 Batch 8 Loss: 1.1779
# Epoch 138 Batch 9 Loss: 1.3319
#
# *** Epoch 138 Loss 1.5100 ***
#
# check point saved!
# Best epoch so far:  138  smallest loss: 1.509960412979126
# Time taken for the epoch 15.988 sec
#
# ========================================
# Epoch 139 Batch 2 Loss: 1.8643
# Epoch 139 Batch 3 Loss: 1.3782
# Epoch 139 Batch 4 Loss: 1.8651
# Epoch 139 Batch 5 Loss: 1.6343
# Epoch 139 Batch 6 Loss: 1.8822
# Epoch 139 Batch 7 Loss: 1.2221
# Epoch 139 Batch 8 Loss: 1.5604
# Epoch 139 Batch 9 Loss: 1.0697
# Epoch 139 Batch 10 Loss: 1.4754
#
# *** Epoch 139 Loss 1.7440 ***
#
# Best epoch so far:  138  smallest loss: 1.509960412979126
# Time taken for the epoch 20.018 sec
#
# ========================================
# Epoch 140 Batch 2 Loss: 2.0073
# Epoch 140 Batch 3 Loss: 1.3515
# Epoch 140 Batch 4 Loss: 1.7661
# Epoch 140 Batch 5 Loss: 1.6329
# Epoch 140 Batch 6 Loss: 1.8525
# Epoch 140 Batch 7 Loss: 1.2395
# Epoch 140 Batch 8 Loss: 1.5936
# Epoch 140 Batch 9 Loss: 1.0215
# Epoch 140 Batch 10 Loss: 1.4713
#
# *** Epoch 140 Loss 1.7421 ***
#
# Best epoch so far:  138  smallest loss: 1.509960412979126
# Time taken for the epoch 17.169 sec
#
# ========================================
# Epoch 141 Batch 2 Loss: 1.7233
# Epoch 141 Batch 3 Loss: 1.4576
# Epoch 141 Batch 4 Loss: 1.8129
# Epoch 141 Batch 5 Loss: 1.5787
# Epoch 141 Batch 6 Loss: 1.7769
# Epoch 141 Batch 7 Loss: 1.2145
# Epoch 141 Batch 8 Loss: 1.5295
# Epoch 141 Batch 9 Loss: 1.0281
# Epoch 141 Batch 10 Loss: 1.4119
#
# *** Epoch 141 Loss 1.6917 ***
# Best epoch so far:  138  smallest loss: 1.509960412979126
# Time taken for the epoch 18.356 sec
#
# ========================================
# Epoch 142 Batch 2 Loss: 1.7210
# Epoch 142 Batch 3 Loss: 1.4466
# Epoch 142 Batch 4 Loss: 1.8032
# Epoch 142 Batch 5 Loss: 1.7123
# Epoch 142 Batch 6 Loss: 1.5344
# Epoch 142 Batch 7 Loss: 1.2583
# Epoch 142 Batch 8 Loss: 1.5538
# Epoch 142 Batch 9 Loss: 1.0751
# Epoch 142 Batch 10 Loss: 1.4615
#
# *** Epoch 142 Loss 1.6958 ***
#
# Best epoch so far:  138  smallest loss: 1.509960412979126
# Time taken for the epoch 18.566 sec
#
# ========================================
# Epoch 143 Batch 2 Loss: 1.6053
# Epoch 143 Batch 3 Loss: 1.4507
# Epoch 143 Batch 4 Loss: 1.6642
# Epoch 143 Batch 5 Loss: 1.8538
# Epoch 143 Batch 6 Loss: 1.3612
# Epoch 143 Batch 7 Loss: 1.4233
# Epoch 143 Batch 8 Loss: 1.3821
# Epoch 143 Batch 9 Loss: 1.0694
# Epoch 143 Batch 10 Loss: 1.5838
#
# *** Epoch 143 Loss 1.6742 ***
#
# Best epoch so far:  138  smallest loss: 1.509960412979126
# Time taken for the epoch 18.875 sec
#
# ========================================
# Epoch 144 Batch 2 Loss: 1.4740
# Epoch 144 Batch 3 Loss: 1.4314
# Epoch 144 Batch 4 Loss: 1.6313
# Epoch 144 Batch 5 Loss: 1.7995
# Epoch 144 Batch 6 Loss: 1.2417
# Epoch 144 Batch 7 Loss: 1.4848
# Epoch 144 Batch 8 Loss: 1.3230
# Epoch 144 Batch 9 Loss: 1.1721
# Epoch 144 Batch 10 Loss: 1.5698
#
# *** Epoch 144 Loss 1.6409 ***
# Best epoch so far:  138  smallest loss: 1.509960412979126
# Time taken for the epoch 18.944 sec
#
# ========================================
# Epoch 145 Batch 2 Loss: 1.2795
# Epoch 145 Batch 3 Loss: 1.5735
# Epoch 145 Batch 4 Loss: 1.6210
# Epoch 145 Batch 5 Loss: 1.6458
# Epoch 145 Batch 6 Loss: 1.2563
# Epoch 145 Batch 7 Loss: 1.4578
# Epoch 145 Batch 8 Loss: 1.2100
# Epoch 145 Batch 9 Loss: 1.1702
# Epoch 145 Batch 10 Loss: 1.6596
#
# *** Epoch 145 Loss 1.6092 ***
#
# Best epoch so far:  138  smallest loss: 1.509960412979126
# Time taken for the epoch 18.025 sec
#
# ========================================
# Epoch 146 Batch 2 Loss: 1.1617
# Epoch 146 Batch 3 Loss: 1.7241
# Epoch 146 Batch 4 Loss: 1.4797
# Epoch 146 Batch 5 Loss: 1.7363
# Epoch 146 Batch 6 Loss: 1.1282
# Epoch 146 Batch 7 Loss: 1.4521
# Epoch 146 Batch 8 Loss: 1.0874
# Epoch 146 Batch 9 Loss: 1.2129
#
# *** Epoch 146 Loss 1.3728 ***
#
# check point saved!
# Best epoch so far:  146  smallest loss: 1.3728030920028687
# Time taken for the epoch 17.053 sec
#
# ========================================
# Epoch 147 Batch 2 Loss: 1.6904
# Epoch 147 Batch 3 Loss: 1.2259
# Epoch 147 Batch 4 Loss: 1.6760
# Epoch 147 Batch 5 Loss: 1.4779
# Epoch 147 Batch 6 Loss: 1.7309
# Epoch 147 Batch 7 Loss: 1.1069
# Epoch 147 Batch 8 Loss: 1.4079
# Epoch 147 Batch 9 Loss: 0.9628
# Epoch 147 Batch 10 Loss: 1.3040
#
# *** Epoch 147 Loss 1.5728 ***
# Best epoch so far:  146  smallest loss: 1.3728030920028687
# Time taken for the epoch 17.620 sec
#
# ========================================
# Epoch 148 Batch 2 Loss: 1.7625
# Epoch 148 Batch 3 Loss: 1.2325
# Epoch 148 Batch 4 Loss: 1.6215
# Epoch 148 Batch 5 Loss: 1.4885
# Epoch 148 Batch 6 Loss: 1.6665
# Epoch 148 Batch 7 Loss: 1.0882
# Epoch 148 Batch 8 Loss: 1.4447
# Epoch 148 Batch 9 Loss: 0.9496
# Epoch 148 Batch 10 Loss: 1.3766
#
# *** Epoch 148 Loss 1.5788 ***
#
# Best epoch so far:  146  smallest loss: 1.3728030920028687
# Time taken for the epoch 17.902 sec
#
# ========================================
# Epoch 149 Batch 2 Loss: 1.5994
# Epoch 149 Batch 3 Loss: 1.3335
# Epoch 149 Batch 4 Loss: 1.6406
# Epoch 149 Batch 5 Loss: 1.4584
# Epoch 149 Batch 6 Loss: 1.6640
# Epoch 149 Batch 7 Loss: 1.1421
# Epoch 149 Batch 8 Loss: 1.4268
# Epoch 149 Batch 9 Loss: 0.9464
# Epoch 149 Batch 10 Loss: 1.2808
#
# *** Epoch 149 Loss 1.5615 ***
#
# Best epoch so far:  146  smallest loss: 1.3728030920028687
# Time taken for the epoch 18.143 sec
#
# ========================================
# Epoch 150 Batch 2 Loss: 1.5719
# Epoch 150 Batch 3 Loss: 1.3905
# Epoch 150 Batch 4 Loss: 1.6730
# Epoch 150 Batch 5 Loss: 1.6210
# Epoch 150 Batch 6 Loss: 1.4087
# Epoch 150 Batch 7 Loss: 1.1758
# Epoch 150 Batch 8 Loss: 1.4828
# Epoch 150 Batch 9 Loss: 1.0590
# Epoch 150 Batch 10 Loss: 1.4197
#
# *** Epoch 150 Loss 1.6003 ***
# Best epoch so far:  146  smallest loss: 1.3728030920028687
# Time taken for the epoch 16.726 sec
#
# ========================================
# Epoch 151 Batch 2 Loss: 1.5125
# Epoch 151 Batch 3 Loss: 1.3596
# Epoch 151 Batch 4 Loss: 1.5520
# Epoch 151 Batch 5 Loss: 1.8431
# Epoch 151 Batch 6 Loss: 1.3306
# Epoch 151 Batch 7 Loss: 1.4089
# Epoch 151 Batch 8 Loss: 1.3283
# Epoch 151 Batch 9 Loss: 1.0089
# Epoch 151 Batch 10 Loss: 1.5077
#
# *** Epoch 151 Loss 1.6065 ***
#
# Best epoch so far:  146  smallest loss: 1.3728030920028687
# Time taken for the epoch 19.326 sec
#
# ========================================
# Epoch 152 Batch 2 Loss: 1.4054
# Epoch 152 Batch 3 Loss: 1.3860
# Epoch 152 Batch 4 Loss: 1.5813
# Epoch 152 Batch 5 Loss: 1.7142
# Epoch 152 Batch 6 Loss: 1.1743
# Epoch 152 Batch 7 Loss: 1.4233
# Epoch 152 Batch 8 Loss: 1.2710
# Epoch 152 Batch 9 Loss: 1.1191
# Epoch 152 Batch 10 Loss: 1.5027
#
# *** Epoch 152 Loss 1.5722 ***
#
# Best epoch so far:  146  smallest loss: 1.3728030920028687
# Time taken for the epoch 15.738 sec
#
# ========================================
# Epoch 153 Batch 2 Loss: 1.2228
# Epoch 153 Batch 3 Loss: 1.4877
# Epoch 153 Batch 4 Loss: 1.5579
# Epoch 153 Batch 5 Loss: 1.5853
# Epoch 153 Batch 6 Loss: 1.2010
# Epoch 153 Batch 7 Loss: 1.3747
# Epoch 153 Batch 8 Loss: 1.1495
# Epoch 153 Batch 9 Loss: 1.1192
# Epoch 153 Batch 10 Loss: 1.5791
#
# *** Epoch 153 Loss 1.5347 ***
# Best epoch so far:  146  smallest loss: 1.3728030920028687
# Time taken for the epoch 17.902 sec
#
# ========================================
# Epoch 154 Batch 2 Loss: 1.0933
# Epoch 154 Batch 3 Loss: 1.6386
# Epoch 154 Batch 4 Loss: 1.4269
# Epoch 154 Batch 5 Loss: 1.6679
# Epoch 154 Batch 6 Loss: 1.0615
# Epoch 154 Batch 7 Loss: 1.3641
# Epoch 154 Batch 8 Loss: 1.0269
# Epoch 154 Batch 9 Loss: 1.1504
#
# *** Epoch 154 Loss 1.3037 ***
#
# check point saved!
# Best epoch so far:  154  smallest loss: 1.3037114143371582
# Time taken for the epoch 16.784 sec
#
# ========================================
# Epoch 155 Batch 2 Loss: 1.6108
# Epoch 155 Batch 3 Loss: 1.1644
# Epoch 155 Batch 4 Loss: 1.5704
# Epoch 155 Batch 5 Loss: 1.3862
# Epoch 155 Batch 6 Loss: 1.6177
# Epoch 155 Batch 7 Loss: 1.0387
# Epoch 155 Batch 8 Loss: 1.3297
# Epoch 155 Batch 9 Loss: 0.9074
# Epoch 155 Batch 10 Loss: 1.2153
#
# *** Epoch 155 Loss 1.4801 ***
#
# Best epoch so far:  154  smallest loss: 1.3037114143371582
# Time taken for the epoch 18.612 sec
#
# ========================================
# Epoch 156 Batch 2 Loss: 1.6449
# Epoch 156 Batch 3 Loss: 1.1468
# Epoch 156 Batch 4 Loss: 1.5078
# Epoch 156 Batch 5 Loss: 1.3848
# Epoch 156 Batch 6 Loss: 1.5562
# Epoch 156 Batch 7 Loss: 1.0046
# Epoch 156 Batch 8 Loss: 1.3477
# Epoch 156 Batch 9 Loss: 0.8798
# Epoch 156 Batch 10 Loss: 1.2428
#
# *** Epoch 156 Loss 1.4644 ***
# Best epoch so far:  154  smallest loss: 1.3037114143371582
# Time taken for the epoch 19.343 sec
#
# ========================================

# %%
test_bot()
# Out:
# ####################
# Greedy| Q: Hello ?  A: she cries and process room sister looks at you want to obey you want to obey you want to obey you want to obey you want to obey you want to obey you want to obey you want to obey you want to obey you want to obey you want to obey you want to obey you want to obey you want to obey you want to obey you want to obey you want to obey you want to obey you
# %
# Greedy| Q: How are you ?  A: i am so i have made time her voice to be i have the best to it i will take it i have the best to it i will take it i have the best to it i will take it i have the best to it i will take it i have the best to it i will take it i have the best to it i will take it i have the best to it i will take it
# %
# Greedy| Q: Are you my friend ?  A: she speaks with authority she speaks with authority she speaks with authority she speaks with authority she speaks with authority she speaks with authority she speaks with authority she speaks with authority she speaks with authority she speaks with authority she speaks with authority she speaks with authority she speaks with authority she speaks with authority she speaks with authority she speaks with authority she speaks with authority she speaks with authority she speaks with authority she speaks with authority she
# %
# Greedy| Q: What are you doing ?  A: i am so much i have ever a moment to it she speaks with a sense of kindness and my side and my side and my side and my side and my side and my side and my side and my side and my side and my side and my side and my side and my side and my side and my side and my side and my side and my side and my side and my side and my side
# %
# Greedy| Q: Who are you ?  A: i have the best to it i will be too much i have made time her voice to it i will be too much i have made time her voice to it i will be too much i have made time her voice to it i will be too much i have made time her voice to it i will be too much i have made time her voice to it i will be too much i have made time her
# %
# Greedy| Q: Do you want to go out ?  A: i am so i am a little bit more calm and her eyes go her eyes go her eyes go her eyes go her eyes go her eyes go her eyes go her eyes go her eyes go her eyes go her eyes go her eyes go her eyes go her eyes go her eyes go her eyes go her eyes go her eyes go her eyes go her eyes go her eyes go her eyes go her eyes go her
# ####################

# %%
answer("What is your name")
# Out:
# Input: what is your name
# Predicted answer: greetings and a threat that she speaks with a small amount of kindness and yet that is real that is soothing and yet that is real that is soothing and yet that is real that is soothing and yet that is real that is soothing and yet that is real that is soothing and yet that is real that is soothing and yet that is real that is soothing and yet that is real that is soothing and yet that is
